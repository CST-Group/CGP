# %% [markdown]
# # Installing Dependencies and accessing Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyctm==0.0.13
# Out:
# Collecting pyctm==0.0.13
#   Downloading pyctm-0.0.13-py3-none-any.whl.metadata (389 bytes)
# Collecting confluent-kafka (from pyctm==0.0.13)
#   Downloading confluent_kafka-2.6.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pyctm==0.0.13) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyctm==0.0.13) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pyctm==0.0.13) (1.5.2)
# Collecting tk (from pyctm==0.0.13)
#   Downloading tk-0.1.0-py3-none-any.whl.metadata (693 bytes)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from pyctm==0.0.13) (2.5.0+cu121)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyctm==0.0.13) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyctm==0.0.13) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyctm==0.0.13) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyctm==0.0.13) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyctm==0.0.13) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyctm==0.0.13) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyctm==0.0.13) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyctm==0.0.13) (2.8.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyctm==0.0.13) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyctm==0.0.13) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyctm==0.0.13) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->pyctm==0.0.13) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->pyctm==0.0.13) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->pyctm==0.0.13) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->pyctm==0.0.13) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->pyctm==0.0.13) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->pyctm==0.0.13) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->pyctm==0.0.13) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pyctm==0.0.13) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->pyctm==0.0.13) (3.0.2)
# Downloading pyctm-0.0.13-py3-none-any.whl (36 kB)
# Downloading confluent_kafka-2.6.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 43.7 MB/s eta 0:00:00
# Downloading tk-0.1.0-py3-none-any.whl (3.9 kB)
# Installing collected packages: tk, confluent-kafka, pyctm
# Successfully installed confluent-kafka-2.6.0 pyctm-0.0.13 tk-0.1.0

# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as ff
import torch.optim as optim
import torch.utils.data as data_utils
from torchvision.utils import make_grid
from torch.utils.data import DataLoader, random_split
from torch.utils.data import Dataset
from torch.optim import lr_scheduler
import matplotlib.pyplot as plt
from collections import OrderedDict
from torch.autograd import Variable
from torchvision import transforms
from torch.utils.tensorboard import SummaryWriter
from torch.nn import Parameter
import torchvision
from torch.nn import TransformerEncoder, TransformerEncoderLayer, TransformerDecoder, TransformerDecoderLayer
from torch.optim.lr_scheduler import StepLR

from torchvision import models
import pandas as pd
import json as json
import numpy as np
from IPython.display import clear_output
from tqdm import tqdm

import math
import time
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"


import seaborn as sns
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, roc_auc_score, roc_curve, auc

from pyctm.representation.sdr_idea_array import SDRIdeaArray

from pyctm.representation.sdr_idea_deserializer import SDRIdeaDeserializer
from pyctm.representation.sdr_idea_serializer import SDRIdeaSerializer
from pyctm.representation.dictionary import Dictionary
from pyctm.representation.idea import Idea

from pyctm.representation.array_dictionary import ArrayDictionary

from pyctm.representation.idea import Idea
from pyctm.representation.sdr_idea_array_serializer import SDRIdeaArraySerializer

from prettytable import PrettyTable

# %%
print("\nChecando GPU...")

print("Dispositivo cuda disponível? ", end='')
use_gpu = False
if torch.cuda.is_available() is True:
    device = torch.device("cuda:0")
    print("sim: " + str(device))
    from torch.cuda import get_device_name
    use_gpu = True
    print("GPU:" + str(get_device_name(0)))
else:
    device = torch.device("cpu")
    print("não. Usando CPU.")
# Out:
# Checando GPU...
# Dispositivo cuda disponível? sim: cuda:0
# GPU:NVIDIA A100-SXM4-40GB

# %% [markdown]
# ## Utils Functions

# %%
import matplotlib.pyplot as plt
import time
from torchvision.utils import make_grid
import torch

def show_tensor_images(image_tensor, num_images=25, size=(1, 28, 28), nrow=4, show=True):
    '''
    Function for visualizing images: Given a tensor of images, number of images, and
    size per image, plots and prints the images in a uniform grid.
    '''
    plt.figure(figsize=(15, 15))

    # Convert tensor to numpy array
    image_array = image_tensor.detach().cpu().numpy()

    # Choose a colormap (e.g., 'viridis') to represent the values
    cmap = 'viridis'

    # Plot each image in the grid
    for i in range(num_images):
        plt.subplot(nrow, nrow, i + 1)
        plt.imshow(image_array[i][0], cmap=cmap, vmin=image_tensor.min(), vmax=image_tensor.max())  # Adiciona vmin e vmax
        plt.axis('off')

    plt.colorbar()

    if show:
        plt.show()

# %%
def weights_init(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)
        if isinstance(m, nn.Linear):
            nn.init.xavier_uniform_(m.weight)
            nn.init.constant_(m.bias, 0)

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from torch.nn import TransformerEncoderLayer, TransformerDecoderLayer
import copy

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

class TransformerXLAttention(nn.Module):
    def __init__(self, d_model, n_head, dropout=0.1):
        super(TransformerXLAttention, self).__init__()
        self.d_model = d_model
        self.n_head = n_head
        self.dropout = dropout

        # Initialize query, key, and value linear transformations
        self.W_Q = nn.Linear(d_model, d_model)
        self.W_K = nn.Linear(d_model, d_model)
        self.W_V = nn.Linear(d_model, d_model)

        # Initialize output linear transformation
        self.W_O = nn.Linear(d_model, d_model)

        # Dropout layer
        self.dropout = nn.Dropout(dropout)

    def forward(self, Q, K, V, mask=None):
        # Linear transformations
        Q = self.W_Q(Q)
        K = self.W_K(K)
        V = self.W_V(V)

        # Split heads
        Q = self.split_heads(Q, self.n_head)
        K = self.split_heads(K, self.n_head)
        V = self.split_heads(V, self.n_head)

        # Scale dot product attention
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_model)

        # Apply mask if provided
        if mask is not None:
            attn_scores = attn_scores.masked_fill(mask == 0, -1e9)

        attn_probs = F.softmax(attn_scores, dim=-1)
        attn_probs = self.dropout(attn_probs)

        # Weighted sum of values
        attn_output = torch.matmul(attn_probs, V)

        # Combine heads
        attn_output = self.combine_heads(attn_output)

        # Linear transformation for output
        attn_output = self.W_O(attn_output)

        return attn_output

    def split_heads(self, x, n_head):
        batch_size, seq_len, d_model = x.size()
        head_dim = d_model // n_head
        x = x.view(batch_size, seq_len, n_head, head_dim)
        return x.transpose(1, 2)

    def combine_heads(self, x):
        batch_size, n_head, seq_len, head_dim = x.size()
        x = x.transpose(1, 2).contiguous()
        return x.view(batch_size, seq_len, n_head * head_dim)


class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

class ResidualLayer(nn.Module):
    def __init__(self, sublayer, input_dim):
        super(ResidualLayer, self).__init__()
        self.sublayer = sublayer
        self.norm = nn.LayerNorm(input_dim)

    def forward(self, x):
        return x + self.sublayer(self.norm(x))

class ConvolutionalEmbeddingLayer1D(nn.Module):
    def __init__(self, input_dim, d_model):
        super(ConvolutionalEmbeddingLayer1D, self).__init__()
        self.conv1 = nn.Conv1d(input_dim, d_model, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(d_model, d_model, kernel_size=3, padding=1)
        self.conv3 = nn.Conv1d(d_model, d_model, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.relu(self.conv1(x.permute(0, 2, 1)))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        return x.permute(0, 2, 1)

class EncoderLayer(nn.Module):
    def __init__(self, d_model, n_head, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = TransformerXLAttention(d_model, n_head, dropout)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask):
        attn_output = self.self_attn(x, x, x, mask)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

class DecoderLayer(nn.Module):
    def __init__(self, d_model, n_head, d_ff, dropout):
        super(DecoderLayer, self).__init__()
        self.self_attn = TransformerXLAttention(d_model, n_head, dropout)
        self.cross_attn = TransformerXLAttention(d_model, n_head, dropout)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, enc_output, src_mask, tgt_mask):
        attn_output = self.self_attn(x, x, x, tgt_mask)
        x = self.norm1(x + self.dropout(attn_output))
        attn_output = self.cross_attn(x, enc_output, enc_output, src_mask)
        x = self.norm2(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm3(x + self.dropout(ff_output))
        return x


class PlanningTransformer(nn.Module):
    def __init__(self, vocabulary_size, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, dropout, max_seq_len=20, device='cpu'):
        super(PlanningTransformer, self).__init__()

        self.vocabulary_size = vocabulary_size
        self.d_model = d_model
        self.max_seq_len = max_seq_len
        self.device = device

        self.encoder_embedding = nn.Embedding(vocabulary_size, d_model)
        self.decoder_embedding = nn.Embedding(vocabulary_size, d_model)

        # Positional Encoding
        self.positional_encoding = PositionalEncoding(d_model, max_seq_len)

        self.encoder_layers = nn.ModuleList([EncoderLayer(d_model, nhead, dim_feedforward, dropout) for _ in range(num_encoder_layers)])
        self.decoder_layers = nn.ModuleList([DecoderLayer(d_model, nhead, dim_feedforward, dropout) for _ in range(num_decoder_layers)])

        self.dropout = nn.Dropout(dropout)

        self.output_layer =nn.Linear(d_model, self.vocabulary_size)

    def generate_mask(self, src, tgt):
        src_mask = (src != 0).unsqueeze(1).unsqueeze(2)
        tgt_mask = (tgt != 0).unsqueeze(1).unsqueeze(3)
        seq_length = tgt.size(1)
        nopeak_mask = (1 - torch.triu(torch.ones(1, seq_length, seq_length), diagonal=1)).bool().to(self.device)
        tgt_mask = tgt_mask & nopeak_mask
        return src_mask, tgt_mask

    def generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask


    def create_positional_encoding(self, max_len, d_model):
        # Create a matrix of positional encodings
        positional_encoding = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        positional_encoding[:, 0::2] = torch.sin(position * div_term)
        positional_encoding[:, 1::2] = torch.cos(position * div_term)
        positional_encoding = positional_encoding.unsqueeze(0)
        return nn.Parameter(positional_encoding, requires_grad=False)

    def forward(self, src, tgt):
        batch_size_tgt, seq_len_tgt = tgt.size()
        batch_size, seq_len = src.size()

        src_mask, tgt_mask = self.generate_mask(src, tgt)

        src_embedded = self.dropout(self.positional_encoding(self.encoder_embedding(src)))
        tgt_embedded = self.dropout(self.positional_encoding(self.decoder_embedding(tgt)))

        enc_output = src_embedded
        for enc_layer in self.encoder_layers:
            enc_output = enc_layer(enc_output, src_mask)

        dec_output = tgt_embedded
        for dec_layer in self.decoder_layers:
            dec_output = dec_layer(dec_output, enc_output, src_mask, tgt_mask)

        output = self.output_layer(dec_output)

        output = output.view(batch_size_tgt, seq_len_tgt, self.vocabulary_size)
        return output

# %% [markdown]
# ## Model Test

# %%
# Hyperparameters
vocabulary_size = 33  # Flattened input size for each of the 20 sequences
d_model = 768  # Size of the transformer layers
nhead = 12  # Number of heads in the multiheadattention models
num_encoder_layers = 2  # Number of sub-encoder-layers in the encoder
num_decoder_layers = 4  # Number of sub-decoder-layers in the decoder
dim_feedforward = 768  # Dimension of the feedforward network model
dropout = 0.3  # Dropout value
learning_rate = 1e-4 # Learning rate
epochs = 100 # Epochs
NGPU = 1 # GPU Number
batch_size = 64
max_seq_len = 626

input = torch.zeros((10, 626)).long()
target = torch.ones((10, 15)).long()

model = PlanningTransformer(vocabulary_size, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, dropout, max_seq_len, device='cpu')
preds = model(input, target)

print(preds.shape)
# Out:
# torch.Size([10, 15, 33])

# %% [markdown]
# # Data Treatments

# %% [markdown]
# ## Dataset Class

# %%
import torch
import torch.nn.functional as F
import numpy as np

import torch
import numpy as np

class PlanDataset(torch.utils.data.Dataset):
    def __init__(self, dataset, transform=None):
        self.dataset = dataset
        self.transform = transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, index):
        input = torch.from_numpy(np.asarray(self.dataset["input"].values[index]))
        label = torch.from_numpy(np.asarray(self.dataset["output"].values[index]))

        input = input.long()
        label = label.long()

        return input, label

# %% [markdown]
# ## Loading Data

# %%
# !gdown --id 13kkDkMDlTOfFU4kNQrEenvMPcDYC64hr
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=13kkDkMDlTOfFU4kNQrEenvMPcDYC64hr
# From (redirected): https://drive.google.com/uc?id=13kkDkMDlTOfFU4kNQrEenvMPcDYC64hr&confirm=t&uuid=39e007ca-46c0-46a8-b74d-549e50f90531
# To: /content/dataPlanSDR35.zip
# 100% 9.50M/9.50M [00:00<00:00, 86.5MB/s]

# %%
# !rm -rf dataPlanSDR/
# !unzip "/content/drive/MyDrive/data/SDR/dataPlanSDR35.zip" -d .
# Out:
# Archive:  /content/drive/MyDrive/data/SDR/dataPlanSDR35.zip
#    creating: ./dataPlanSDR/
#   inflating: ./dataPlanSDR/dataPlanSDR_1606.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1609.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1610.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1614.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1617.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1618.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1620.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1623.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1625.json
#   inflating: ./dataPlanSDR/dataPlanSDR_0.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2.json
#   inflating: ./dataPlanSDR/dataPlanSDR_6.json
#   inflating: ./dataPlanSDR/dataPlanSDR_7.json
#   inflating: ./dataPlanSDR/dataPlanSDR_10.json
#   inflating: ./dataPlanSDR/dataPlanSDR_15.json
#   inflating: ./dataPlanSDR/dataPlanSDR_16.json
#   inflating: ./dataPlanSDR/dataPlanSDR_20.json
#   inflating: ./dataPlanSDR/dataPlanSDR_23.json
#   inflating: ./dataPlanSDR/dataPlanSDR_24.json
#   inflating: ./dataPlanSDR/dataPlanSDR_26.json
#   inflating: ./dataPlanSDR/dataPlanSDR_30.json
#   inflating: ./dataPlanSDR/dataPlanSDR_37.json
#   inflating: ./dataPlanSDR/dataPlanSDR_40.json
#   inflating: ./dataPlanSDR/dataPlanSDR_42.json
#   inflating: ./dataPlanSDR/dataPlanSDR_43.json
#   inflating: ./dataPlanSDR/dataPlanSDR_46.json
#   inflating: ./dataPlanSDR/dataPlanSDR_51.json
#   inflating: ./dataPlanSDR/dataPlanSDR_53.json
#   inflating: ./dataPlanSDR/dataPlanSDR_54.json
#   inflating: ./dataPlanSDR/dataPlanSDR_55.json
#   inflating: ./dataPlanSDR/dataPlanSDR_57.json
#   inflating: ./dataPlanSDR/dataPlanSDR_58.json
#   inflating: ./dataPlanSDR/dataPlanSDR_59.json
#   inflating: ./dataPlanSDR/dataPlanSDR_65.json
#   inflating: ./dataPlanSDR/dataPlanSDR_67.json
#   inflating: ./dataPlanSDR/dataPlanSDR_71.json
#   inflating: ./dataPlanSDR/dataPlanSDR_74.json
#   inflating: ./dataPlanSDR/dataPlanSDR_76.json
#   inflating: ./dataPlanSDR/dataPlanSDR_78.json
#   inflating: ./dataPlanSDR/dataPlanSDR_81.json
#   inflating: ./dataPlanSDR/dataPlanSDR_83.json
#   inflating: ./dataPlanSDR/dataPlanSDR_87.json
#   inflating: ./dataPlanSDR/dataPlanSDR_89.json
#   inflating: ./dataPlanSDR/dataPlanSDR_90.json
#   inflating: ./dataPlanSDR/dataPlanSDR_94.json
#   inflating: ./dataPlanSDR/dataPlanSDR_105.json
#   inflating: ./dataPlanSDR/dataPlanSDR_106.json
#   inflating: ./dataPlanSDR/dataPlanSDR_108.json
#   inflating: ./dataPlanSDR/dataPlanSDR_109.json
#   inflating: ./dataPlanSDR/dataPlanSDR_115.json
#   inflating: ./dataPlanSDR/dataPlanSDR_116.json
#   inflating: ./dataPlanSDR/dataPlanSDR_119.json
#   inflating: ./dataPlanSDR/dataPlanSDR_124.json
#   inflating: ./dataPlanSDR/dataPlanSDR_125.json
#   inflating: ./dataPlanSDR/dataPlanSDR_126.json
#   inflating: ./dataPlanSDR/dataPlanSDR_127.json
#   inflating: ./dataPlanSDR/dataPlanSDR_133.json
#   inflating: ./dataPlanSDR/dataPlanSDR_134.json
#   inflating: ./dataPlanSDR/dataPlanSDR_139.json
#   inflating: ./dataPlanSDR/dataPlanSDR_140.json
#   inflating: ./dataPlanSDR/dataPlanSDR_141.json
#   inflating: ./dataPlanSDR/dataPlanSDR_144.json
#   inflating: ./dataPlanSDR/dataPlanSDR_147.json
#   inflating: ./dataPlanSDR/dataPlanSDR_152.json
#   inflating: ./dataPlanSDR/dataPlanSDR_153.json
#   inflating: ./dataPlanSDR/dataPlanSDR_155.json
#   inflating: ./dataPlanSDR/dataPlanSDR_160.json
#   inflating: ./dataPlanSDR/dataPlanSDR_161.json
#   inflating: ./dataPlanSDR/dataPlanSDR_162.json
#   inflating: ./dataPlanSDR/dataPlanSDR_164.json
#   inflating: ./dataPlanSDR/dataPlanSDR_167.json
#   inflating: ./dataPlanSDR/dataPlanSDR_169.json
#   inflating: ./dataPlanSDR/dataPlanSDR_170.json
#   inflating: ./dataPlanSDR/dataPlanSDR_174.json
#   inflating: ./dataPlanSDR/dataPlanSDR_175.json
#   inflating: ./dataPlanSDR/dataPlanSDR_182.json
#   inflating: ./dataPlanSDR/dataPlanSDR_183.json
#   inflating: ./dataPlanSDR/dataPlanSDR_184.json
#   inflating: ./dataPlanSDR/dataPlanSDR_189.json
#   inflating: ./dataPlanSDR/dataPlanSDR_192.json
#   inflating: ./dataPlanSDR/dataPlanSDR_202.json
#   inflating: ./dataPlanSDR/dataPlanSDR_203.json
#   inflating: ./dataPlanSDR/dataPlanSDR_204.json
#   inflating: ./dataPlanSDR/dataPlanSDR_209.json
#   inflating: ./dataPlanSDR/dataPlanSDR_217.json
#   inflating: ./dataPlanSDR/dataPlanSDR_218.json
#   inflating: ./dataPlanSDR/dataPlanSDR_220.json
#   inflating: ./dataPlanSDR/dataPlanSDR_223.json
#   inflating: ./dataPlanSDR/dataPlanSDR_225.json
#   inflating: ./dataPlanSDR/dataPlanSDR_228.json
#   inflating: ./dataPlanSDR/dataPlanSDR_231.json
#   inflating: ./dataPlanSDR/dataPlanSDR_232.json
#   inflating: ./dataPlanSDR/dataPlanSDR_235.json
#   inflating: ./dataPlanSDR/dataPlanSDR_240.json
#   inflating: ./dataPlanSDR/dataPlanSDR_243.json
#   inflating: ./dataPlanSDR/dataPlanSDR_244.json
#   inflating: ./dataPlanSDR/dataPlanSDR_247.json
#   inflating: ./dataPlanSDR/dataPlanSDR_248.json
#   inflating: ./dataPlanSDR/dataPlanSDR_249.json
#   inflating: ./dataPlanSDR/dataPlanSDR_251.json
#   inflating: ./dataPlanSDR/dataPlanSDR_252.json
#   inflating: ./dataPlanSDR/dataPlanSDR_255.json
#   inflating: ./dataPlanSDR/dataPlanSDR_256.json
#   inflating: ./dataPlanSDR/dataPlanSDR_259.json
#   inflating: ./dataPlanSDR/dataPlanSDR_260.json
#   inflating: ./dataPlanSDR/dataPlanSDR_264.json
#   inflating: ./dataPlanSDR/dataPlanSDR_265.json
#   inflating: ./dataPlanSDR/dataPlanSDR_272.json
#   inflating: ./dataPlanSDR/dataPlanSDR_276.json
#   inflating: ./dataPlanSDR/dataPlanSDR_278.json
#   inflating: ./dataPlanSDR/dataPlanSDR_279.json
#   inflating: ./dataPlanSDR/dataPlanSDR_281.json
#   inflating: ./dataPlanSDR/dataPlanSDR_282.json
#   inflating: ./dataPlanSDR/dataPlanSDR_283.json
#   inflating: ./dataPlanSDR/dataPlanSDR_285.json
#   inflating: ./dataPlanSDR/dataPlanSDR_287.json
#   inflating: ./dataPlanSDR/dataPlanSDR_288.json
#   inflating: ./dataPlanSDR/dataPlanSDR_293.json
#   inflating: ./dataPlanSDR/dataPlanSDR_296.json
#   inflating: ./dataPlanSDR/dataPlanSDR_298.json
#   inflating: ./dataPlanSDR/dataPlanSDR_299.json
#   inflating: ./dataPlanSDR/dataPlanSDR_300.json
#   inflating: ./dataPlanSDR/dataPlanSDR_306.json
#   inflating: ./dataPlanSDR/dataPlanSDR_307.json
#   inflating: ./dataPlanSDR/dataPlanSDR_314.json
#   inflating: ./dataPlanSDR/dataPlanSDR_315.json
#   inflating: ./dataPlanSDR/dataPlanSDR_316.json
#   inflating: ./dataPlanSDR/dataPlanSDR_320.json
#   inflating: ./dataPlanSDR/dataPlanSDR_323.json
#   inflating: ./dataPlanSDR/dataPlanSDR_324.json
#   inflating: ./dataPlanSDR/dataPlanSDR_327.json
#   inflating: ./dataPlanSDR/dataPlanSDR_329.json
#   inflating: ./dataPlanSDR/dataPlanSDR_330.json
#   inflating: ./dataPlanSDR/dataPlanSDR_333.json
#   inflating: ./dataPlanSDR/dataPlanSDR_334.json
#   inflating: ./dataPlanSDR/dataPlanSDR_341.json
#   inflating: ./dataPlanSDR/dataPlanSDR_346.json
#   inflating: ./dataPlanSDR/dataPlanSDR_349.json
#   inflating: ./dataPlanSDR/dataPlanSDR_350.json
#   inflating: ./dataPlanSDR/dataPlanSDR_356.json
#   inflating: ./dataPlanSDR/dataPlanSDR_359.json
#   inflating: ./dataPlanSDR/dataPlanSDR_361.json
#   inflating: ./dataPlanSDR/dataPlanSDR_363.json
#   inflating: ./dataPlanSDR/dataPlanSDR_364.json
#   inflating: ./dataPlanSDR/dataPlanSDR_365.json
#   inflating: ./dataPlanSDR/dataPlanSDR_367.json
#   inflating: ./dataPlanSDR/dataPlanSDR_371.json
#   inflating: ./dataPlanSDR/dataPlanSDR_372.json
#   inflating: ./dataPlanSDR/dataPlanSDR_373.json
#   inflating: ./dataPlanSDR/dataPlanSDR_374.json
#   inflating: ./dataPlanSDR/dataPlanSDR_375.json
#   inflating: ./dataPlanSDR/dataPlanSDR_376.json
#   inflating: ./dataPlanSDR/dataPlanSDR_377.json
#   inflating: ./dataPlanSDR/dataPlanSDR_383.json
#   inflating: ./dataPlanSDR/dataPlanSDR_388.json
#   inflating: ./dataPlanSDR/dataPlanSDR_389.json
#   inflating: ./dataPlanSDR/dataPlanSDR_390.json
#   inflating: ./dataPlanSDR/dataPlanSDR_395.json
#   inflating: ./dataPlanSDR/dataPlanSDR_397.json
#   inflating: ./dataPlanSDR/dataPlanSDR_401.json
#   inflating: ./dataPlanSDR/dataPlanSDR_404.json
#   inflating: ./dataPlanSDR/dataPlanSDR_414.json
#   inflating: ./dataPlanSDR/dataPlanSDR_419.json
#   inflating: ./dataPlanSDR/dataPlanSDR_421.json
#   inflating: ./dataPlanSDR/dataPlanSDR_428.json
#   inflating: ./dataPlanSDR/dataPlanSDR_429.json
#   inflating: ./dataPlanSDR/dataPlanSDR_431.json
#   inflating: ./dataPlanSDR/dataPlanSDR_434.json
#   inflating: ./dataPlanSDR/dataPlanSDR_439.json
#   inflating: ./dataPlanSDR/dataPlanSDR_442.json
#   inflating: ./dataPlanSDR/dataPlanSDR_443.json
#   inflating: ./dataPlanSDR/dataPlanSDR_452.json
#   inflating: ./dataPlanSDR/dataPlanSDR_453.json
#   inflating: ./dataPlanSDR/dataPlanSDR_454.json
#   inflating: ./dataPlanSDR/dataPlanSDR_455.json
#   inflating: ./dataPlanSDR/dataPlanSDR_456.json
#   inflating: ./dataPlanSDR/dataPlanSDR_458.json
#   inflating: ./dataPlanSDR/dataPlanSDR_459.json
#   inflating: ./dataPlanSDR/dataPlanSDR_460.json
#   inflating: ./dataPlanSDR/dataPlanSDR_461.json
#   inflating: ./dataPlanSDR/dataPlanSDR_466.json
#   inflating: ./dataPlanSDR/dataPlanSDR_467.json
#   inflating: ./dataPlanSDR/dataPlanSDR_469.json
#   inflating: ./dataPlanSDR/dataPlanSDR_470.json
#   inflating: ./dataPlanSDR/dataPlanSDR_476.json
#   inflating: ./dataPlanSDR/dataPlanSDR_478.json
#   inflating: ./dataPlanSDR/dataPlanSDR_479.json
#   inflating: ./dataPlanSDR/dataPlanSDR_481.json
#   inflating: ./dataPlanSDR/dataPlanSDR_489.json
#   inflating: ./dataPlanSDR/dataPlanSDR_493.json
#   inflating: ./dataPlanSDR/dataPlanSDR_495.json
#   inflating: ./dataPlanSDR/dataPlanSDR_496.json
#   inflating: ./dataPlanSDR/dataPlanSDR_500.json
#   inflating: ./dataPlanSDR/dataPlanSDR_505.json
#   inflating: ./dataPlanSDR/dataPlanSDR_514.json
#   inflating: ./dataPlanSDR/dataPlanSDR_515.json
#   inflating: ./dataPlanSDR/dataPlanSDR_522.json
#   inflating: ./dataPlanSDR/dataPlanSDR_524.json
#   inflating: ./dataPlanSDR/dataPlanSDR_526.json
#   inflating: ./dataPlanSDR/dataPlanSDR_527.json
#   inflating: ./dataPlanSDR/dataPlanSDR_532.json
#   inflating: ./dataPlanSDR/dataPlanSDR_533.json
#   inflating: ./dataPlanSDR/dataPlanSDR_538.json
#   inflating: ./dataPlanSDR/dataPlanSDR_540.json
#   inflating: ./dataPlanSDR/dataPlanSDR_545.json
#   inflating: ./dataPlanSDR/dataPlanSDR_546.json
#   inflating: ./dataPlanSDR/dataPlanSDR_548.json
#   inflating: ./dataPlanSDR/dataPlanSDR_551.json
#   inflating: ./dataPlanSDR/dataPlanSDR_557.json
#   inflating: ./dataPlanSDR/dataPlanSDR_559.json
#   inflating: ./dataPlanSDR/dataPlanSDR_560.json
#   inflating: ./dataPlanSDR/dataPlanSDR_562.json
#   inflating: ./dataPlanSDR/dataPlanSDR_563.json
#   inflating: ./dataPlanSDR/dataPlanSDR_570.json
#   inflating: ./dataPlanSDR/dataPlanSDR_575.json
#   inflating: ./dataPlanSDR/dataPlanSDR_577.json
#   inflating: ./dataPlanSDR/dataPlanSDR_579.json
#   inflating: ./dataPlanSDR/dataPlanSDR_580.json
#   inflating: ./dataPlanSDR/dataPlanSDR_581.json
#   inflating: ./dataPlanSDR/dataPlanSDR_582.json
#   inflating: ./dataPlanSDR/dataPlanSDR_583.json
#   inflating: ./dataPlanSDR/dataPlanSDR_586.json
#   inflating: ./dataPlanSDR/dataPlanSDR_587.json
#   inflating: ./dataPlanSDR/dataPlanSDR_588.json
#   inflating: ./dataPlanSDR/dataPlanSDR_589.json
#   inflating: ./dataPlanSDR/dataPlanSDR_591.json
#   inflating: ./dataPlanSDR/dataPlanSDR_595.json
#   inflating: ./dataPlanSDR/dataPlanSDR_596.json
#   inflating: ./dataPlanSDR/dataPlanSDR_598.json
#   inflating: ./dataPlanSDR/dataPlanSDR_599.json
#   inflating: ./dataPlanSDR/dataPlanSDR_600.json
#   inflating: ./dataPlanSDR/dataPlanSDR_602.json
#   inflating: ./dataPlanSDR/dataPlanSDR_603.json
#   inflating: ./dataPlanSDR/dataPlanSDR_604.json
#   inflating: ./dataPlanSDR/dataPlanSDR_606.json
#   inflating: ./dataPlanSDR/dataPlanSDR_607.json
#   inflating: ./dataPlanSDR/dataPlanSDR_610.json
#   inflating: ./dataPlanSDR/dataPlanSDR_612.json
#   inflating: ./dataPlanSDR/dataPlanSDR_613.json
#   inflating: ./dataPlanSDR/dataPlanSDR_616.json
#   inflating: ./dataPlanSDR/dataPlanSDR_622.json
#   inflating: ./dataPlanSDR/dataPlanSDR_623.json
#   inflating: ./dataPlanSDR/dataPlanSDR_625.json
#   inflating: ./dataPlanSDR/dataPlanSDR_626.json
#   inflating: ./dataPlanSDR/dataPlanSDR_630.json
#   inflating: ./dataPlanSDR/dataPlanSDR_633.json
#   inflating: ./dataPlanSDR/dataPlanSDR_639.json
#   inflating: ./dataPlanSDR/dataPlanSDR_644.json
#   inflating: ./dataPlanSDR/dataPlanSDR_646.json
#   inflating: ./dataPlanSDR/dataPlanSDR_647.json
#   inflating: ./dataPlanSDR/dataPlanSDR_648.json
#   inflating: ./dataPlanSDR/dataPlanSDR_649.json
#   inflating: ./dataPlanSDR/dataPlanSDR_653.json
#   inflating: ./dataPlanSDR/dataPlanSDR_655.json
#   inflating: ./dataPlanSDR/dataPlanSDR_662.json
#   inflating: ./dataPlanSDR/dataPlanSDR_663.json
#   inflating: ./dataPlanSDR/dataPlanSDR_666.json
#   inflating: ./dataPlanSDR/dataPlanSDR_667.json
#   inflating: ./dataPlanSDR/dataPlanSDR_671.json
#   inflating: ./dataPlanSDR/dataPlanSDR_672.json
#   inflating: ./dataPlanSDR/dataPlanSDR_676.json
#   inflating: ./dataPlanSDR/dataPlanSDR_680.json
#   inflating: ./dataPlanSDR/dataPlanSDR_681.json
#   inflating: ./dataPlanSDR/dataPlanSDR_682.json
#   inflating: ./dataPlanSDR/dataPlanSDR_684.json
#   inflating: ./dataPlanSDR/dataPlanSDR_687.json
#   inflating: ./dataPlanSDR/dataPlanSDR_688.json
#   inflating: ./dataPlanSDR/dataPlanSDR_690.json
#   inflating: ./dataPlanSDR/dataPlanSDR_691.json
#   inflating: ./dataPlanSDR/dataPlanSDR_692.json
#   inflating: ./dataPlanSDR/dataPlanSDR_693.json
#   inflating: ./dataPlanSDR/dataPlanSDR_695.json
#   inflating: ./dataPlanSDR/dataPlanSDR_699.json
#   inflating: ./dataPlanSDR/dataPlanSDR_700.json
#   inflating: ./dataPlanSDR/dataPlanSDR_701.json
#   inflating: ./dataPlanSDR/dataPlanSDR_702.json
#   inflating: ./dataPlanSDR/dataPlanSDR_703.json
#   inflating: ./dataPlanSDR/dataPlanSDR_704.json
#   inflating: ./dataPlanSDR/dataPlanSDR_708.json
#   inflating: ./dataPlanSDR/dataPlanSDR_711.json
#   inflating: ./dataPlanSDR/dataPlanSDR_713.json
#   inflating: ./dataPlanSDR/dataPlanSDR_714.json
#   inflating: ./dataPlanSDR/dataPlanSDR_715.json
#   inflating: ./dataPlanSDR/dataPlanSDR_718.json
#   inflating: ./dataPlanSDR/dataPlanSDR_724.json
#   inflating: ./dataPlanSDR/dataPlanSDR_725.json
#   inflating: ./dataPlanSDR/dataPlanSDR_728.json
#   inflating: ./dataPlanSDR/dataPlanSDR_730.json
#   inflating: ./dataPlanSDR/dataPlanSDR_734.json
#   inflating: ./dataPlanSDR/dataPlanSDR_735.json
#   inflating: ./dataPlanSDR/dataPlanSDR_736.json
#   inflating: ./dataPlanSDR/dataPlanSDR_737.json
#   inflating: ./dataPlanSDR/dataPlanSDR_739.json
#   inflating: ./dataPlanSDR/dataPlanSDR_740.json
#   inflating: ./dataPlanSDR/dataPlanSDR_742.json
#   inflating: ./dataPlanSDR/dataPlanSDR_744.json
#   inflating: ./dataPlanSDR/dataPlanSDR_747.json
#   inflating: ./dataPlanSDR/dataPlanSDR_749.json
#   inflating: ./dataPlanSDR/dataPlanSDR_750.json
#   inflating: ./dataPlanSDR/dataPlanSDR_754.json
#   inflating: ./dataPlanSDR/dataPlanSDR_757.json
#   inflating: ./dataPlanSDR/dataPlanSDR_758.json
#   inflating: ./dataPlanSDR/dataPlanSDR_759.json
#   inflating: ./dataPlanSDR/dataPlanSDR_768.json
#   inflating: ./dataPlanSDR/dataPlanSDR_772.json
#   inflating: ./dataPlanSDR/dataPlanSDR_773.json
#   inflating: ./dataPlanSDR/dataPlanSDR_775.json
#   inflating: ./dataPlanSDR/dataPlanSDR_778.json
#   inflating: ./dataPlanSDR/dataPlanSDR_779.json
#   inflating: ./dataPlanSDR/dataPlanSDR_780.json
#   inflating: ./dataPlanSDR/dataPlanSDR_783.json
#   inflating: ./dataPlanSDR/dataPlanSDR_785.json
#   inflating: ./dataPlanSDR/dataPlanSDR_786.json
#   inflating: ./dataPlanSDR/dataPlanSDR_787.json
#   inflating: ./dataPlanSDR/dataPlanSDR_788.json
#   inflating: ./dataPlanSDR/dataPlanSDR_791.json
#   inflating: ./dataPlanSDR/dataPlanSDR_792.json
#   inflating: ./dataPlanSDR/dataPlanSDR_794.json
#   inflating: ./dataPlanSDR/dataPlanSDR_795.json
#   inflating: ./dataPlanSDR/dataPlanSDR_796.json
#   inflating: ./dataPlanSDR/dataPlanSDR_797.json
#   inflating: ./dataPlanSDR/dataPlanSDR_798.json
#   inflating: ./dataPlanSDR/dataPlanSDR_803.json
#   inflating: ./dataPlanSDR/dataPlanSDR_806.json
#   inflating: ./dataPlanSDR/dataPlanSDR_807.json
#   inflating: ./dataPlanSDR/dataPlanSDR_818.json
#   inflating: ./dataPlanSDR/dataPlanSDR_819.json
#   inflating: ./dataPlanSDR/dataPlanSDR_822.json
#   inflating: ./dataPlanSDR/dataPlanSDR_825.json
#   inflating: ./dataPlanSDR/dataPlanSDR_829.json
#   inflating: ./dataPlanSDR/dataPlanSDR_831.json
#   inflating: ./dataPlanSDR/dataPlanSDR_832.json
#   inflating: ./dataPlanSDR/dataPlanSDR_833.json
#   inflating: ./dataPlanSDR/dataPlanSDR_834.json
#   inflating: ./dataPlanSDR/dataPlanSDR_838.json
#   inflating: ./dataPlanSDR/dataPlanSDR_839.json
#   inflating: ./dataPlanSDR/dataPlanSDR_841.json
#   inflating: ./dataPlanSDR/dataPlanSDR_842.json
#   inflating: ./dataPlanSDR/dataPlanSDR_846.json
#   inflating: ./dataPlanSDR/dataPlanSDR_849.json
#   inflating: ./dataPlanSDR/dataPlanSDR_855.json
#   inflating: ./dataPlanSDR/dataPlanSDR_858.json
#   inflating: ./dataPlanSDR/dataPlanSDR_859.json
#   inflating: ./dataPlanSDR/dataPlanSDR_860.json
#   inflating: ./dataPlanSDR/dataPlanSDR_861.json
#   inflating: ./dataPlanSDR/dataPlanSDR_863.json
#   inflating: ./dataPlanSDR/dataPlanSDR_867.json
#   inflating: ./dataPlanSDR/dataPlanSDR_870.json
#   inflating: ./dataPlanSDR/dataPlanSDR_871.json
#   inflating: ./dataPlanSDR/dataPlanSDR_873.json
#   inflating: ./dataPlanSDR/dataPlanSDR_874.json
#   inflating: ./dataPlanSDR/dataPlanSDR_876.json
#   inflating: ./dataPlanSDR/dataPlanSDR_880.json
#   inflating: ./dataPlanSDR/dataPlanSDR_882.json
#   inflating: ./dataPlanSDR/dataPlanSDR_883.json
#   inflating: ./dataPlanSDR/dataPlanSDR_884.json
#   inflating: ./dataPlanSDR/dataPlanSDR_886.json
#   inflating: ./dataPlanSDR/dataPlanSDR_894.json
#   inflating: ./dataPlanSDR/dataPlanSDR_895.json
#   inflating: ./dataPlanSDR/dataPlanSDR_903.json
#   inflating: ./dataPlanSDR/dataPlanSDR_905.json
#   inflating: ./dataPlanSDR/dataPlanSDR_906.json
#   inflating: ./dataPlanSDR/dataPlanSDR_908.json
#   inflating: ./dataPlanSDR/dataPlanSDR_909.json
#   inflating: ./dataPlanSDR/dataPlanSDR_911.json
#   inflating: ./dataPlanSDR/dataPlanSDR_912.json
#   inflating: ./dataPlanSDR/dataPlanSDR_913.json
#   inflating: ./dataPlanSDR/dataPlanSDR_914.json
#   inflating: ./dataPlanSDR/dataPlanSDR_917.json
#   inflating: ./dataPlanSDR/dataPlanSDR_922.json
#   inflating: ./dataPlanSDR/dataPlanSDR_927.json
#   inflating: ./dataPlanSDR/dataPlanSDR_928.json
#   inflating: ./dataPlanSDR/dataPlanSDR_930.json
#   inflating: ./dataPlanSDR/dataPlanSDR_936.json
#   inflating: ./dataPlanSDR/dataPlanSDR_937.json
#   inflating: ./dataPlanSDR/dataPlanSDR_938.json
#   inflating: ./dataPlanSDR/dataPlanSDR_943.json
#   inflating: ./dataPlanSDR/dataPlanSDR_944.json
#   inflating: ./dataPlanSDR/dataPlanSDR_945.json
#   inflating: ./dataPlanSDR/dataPlanSDR_948.json
#   inflating: ./dataPlanSDR/dataPlanSDR_949.json
#   inflating: ./dataPlanSDR/dataPlanSDR_950.json
#   inflating: ./dataPlanSDR/dataPlanSDR_951.json
#   inflating: ./dataPlanSDR/dataPlanSDR_954.json
#   inflating: ./dataPlanSDR/dataPlanSDR_955.json
#   inflating: ./dataPlanSDR/dataPlanSDR_957.json
#   inflating: ./dataPlanSDR/dataPlanSDR_958.json
#   inflating: ./dataPlanSDR/dataPlanSDR_960.json
#   inflating: ./dataPlanSDR/dataPlanSDR_961.json
#   inflating: ./dataPlanSDR/dataPlanSDR_962.json
#   inflating: ./dataPlanSDR/dataPlanSDR_963.json
#   inflating: ./dataPlanSDR/dataPlanSDR_965.json
#   inflating: ./dataPlanSDR/dataPlanSDR_966.json
#   inflating: ./dataPlanSDR/dataPlanSDR_967.json
#   inflating: ./dataPlanSDR/dataPlanSDR_969.json
#   inflating: ./dataPlanSDR/dataPlanSDR_976.json
#   inflating: ./dataPlanSDR/dataPlanSDR_977.json
#   inflating: ./dataPlanSDR/dataPlanSDR_981.json
#   inflating: ./dataPlanSDR/dataPlanSDR_983.json
#   inflating: ./dataPlanSDR/dataPlanSDR_987.json
#   inflating: ./dataPlanSDR/dataPlanSDR_989.json
#   inflating: ./dataPlanSDR/dataPlanSDR_990.json
#   inflating: ./dataPlanSDR/dataPlanSDR_992.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1004.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1005.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1008.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1010.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1014.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1018.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1022.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1023.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1028.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1031.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1035.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1038.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1040.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1044.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1045.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1046.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1048.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1049.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1050.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1051.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1052.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1053.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1056.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1067.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1068.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1069.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1073.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1077.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1079.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1086.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1090.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1092.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1094.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1095.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1096.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1097.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1099.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1100.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1103.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1109.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1110.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1114.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1115.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1120.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1121.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1124.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1133.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1134.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1135.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1137.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1140.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1141.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1148.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1151.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1153.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1154.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1156.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1158.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1159.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1162.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1163.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1165.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1166.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1168.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1172.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1175.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1178.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1179.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1182.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1183.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1184.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1185.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1186.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1187.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1188.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1190.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1202.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1205.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1209.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1210.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1214.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1215.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1219.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1221.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1224.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1226.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1229.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1233.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1234.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1235.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1237.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1239.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1241.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1242.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1245.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1246.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1248.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1250.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1251.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1252.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1255.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1258.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1259.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1262.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1268.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1272.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1274.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1282.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1284.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1285.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1288.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1289.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1290.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1292.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1293.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1296.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1298.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1299.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1301.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1307.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1308.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1309.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1310.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1314.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1315.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1317.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1318.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1321.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1322.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1326.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1327.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1332.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1334.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1335.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1336.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1337.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1339.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1343.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1346.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1347.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1350.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1351.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1355.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1356.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1358.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1359.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1360.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1366.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1367.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1368.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1374.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1382.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1384.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1388.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1391.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1405.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1426.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1429.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1441.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1443.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1444.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1445.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1450.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1454.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1456.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1460.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1462.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1463.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1467.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1468.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1469.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1470.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1475.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1479.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1482.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1485.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1487.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1489.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1490.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1491.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1493.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1496.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1500.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1501.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1507.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1508.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1510.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1514.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1516.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1525.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1527.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1528.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1531.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1532.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1537.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1538.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1541.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1543.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1545.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1546.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1547.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1548.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1552.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1553.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1555.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1556.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1557.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1559.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1560.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1561.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1563.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1566.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1567.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1572.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1573.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1575.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1577.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1588.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1596.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1598.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1602.json
#   inflating: ./dataPlanSDR/dictionary.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1630.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1631.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1632.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1635.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1636.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1640.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1641.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1644.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1645.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1646.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1650.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1651.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1653.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1655.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1656.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1659.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1666.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1670.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1674.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1676.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1677.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1678.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1680.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1681.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1684.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1685.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1687.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1691.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1694.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1695.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1697.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1699.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1700.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1702.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1703.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1704.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1705.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1707.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1709.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1713.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1716.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1717.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1723.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1724.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1726.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1728.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1731.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1734.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1735.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1736.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1738.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1739.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1740.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1741.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1743.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1747.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1750.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1751.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1753.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1755.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1756.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1759.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1763.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1764.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1768.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1769.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1772.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1773.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1774.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1775.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1778.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1784.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1786.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1787.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1788.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1790.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1792.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1795.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1799.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1802.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1806.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1808.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1810.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1811.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1817.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1818.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1819.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1821.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1822.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1825.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1826.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1829.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1832.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1835.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1836.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1837.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1838.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1843.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1845.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1847.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1851.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1856.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1858.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1860.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1862.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1863.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1865.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1867.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1868.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1873.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1874.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1876.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1880.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1883.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1884.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1885.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1886.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1888.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1890.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1893.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1895.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1902.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1910.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1911.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1912.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1913.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1917.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1918.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1919.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1920.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1926.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1929.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1930.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1932.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1934.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1935.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1937.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1940.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1942.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1948.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1949.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1950.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1951.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1952.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1953.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1957.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1959.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1961.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1964.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1965.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1967.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1970.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1977.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1978.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1979.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1980.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1981.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1982.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1986.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1987.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1989.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1992.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1993.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1994.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1995.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1996.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1997.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1998.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1999.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2000.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2002.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2005.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2006.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2007.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2009.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2014.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2015.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2017.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2020.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2024.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2034.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2036.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2037.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2038.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2040.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2041.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2042.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2045.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2046.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2047.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2049.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2050.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2052.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2054.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2057.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2058.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2059.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2060.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2061.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2062.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2066.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2067.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2070.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2072.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2073.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2074.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2077.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2078.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2081.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2082.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2087.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2089.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2090.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2092.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2094.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2098.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2100.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2101.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2103.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2105.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2106.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2111.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2112.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2117.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2119.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2129.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2130.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2132.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2134.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2135.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2136.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2137.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2147.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2148.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2150.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2153.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2156.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2158.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2161.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2163.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2165.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2167.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2171.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2172.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2174.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2178.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2180.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2181.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2184.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2187.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2192.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2193.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2194.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2195.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2200.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2202.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2203.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2206.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2207.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2214.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2217.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2219.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2222.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2223.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2225.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2226.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2227.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2233.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2237.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2241.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2243.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2244.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2246.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2247.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2248.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2250.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2251.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2254.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2257.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2258.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2259.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2261.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2263.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2264.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2265.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2266.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2268.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2276.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2279.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2280.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2282.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2284.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2288.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2289.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2292.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2293.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2294.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2295.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2296.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2298.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2300.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2302.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2304.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2309.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2310.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2311.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2312.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2313.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2315.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2318.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2319.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2322.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2326.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2330.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2333.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2342.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2344.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2349.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2350.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2353.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2354.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2355.json
# ...
#   inflating: ./dataPlanSDR/dataPlanSDR_971.json
#   inflating: ./dataPlanSDR/dataPlanSDR_972.json
#   inflating: ./dataPlanSDR/dataPlanSDR_973.json
#   inflating: ./dataPlanSDR/dataPlanSDR_979.json
#   inflating: ./dataPlanSDR/dataPlanSDR_980.json
#   inflating: ./dataPlanSDR/dataPlanSDR_986.json
#   inflating: ./dataPlanSDR/dataPlanSDR_988.json
#   inflating: ./dataPlanSDR/dataPlanSDR_991.json
#   inflating: ./dataPlanSDR/dataPlanSDR_993.json
#   inflating: ./dataPlanSDR/dataPlanSDR_994.json
#   inflating: ./dataPlanSDR/dataPlanSDR_997.json
#   inflating: ./dataPlanSDR/dataPlanSDR_999.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1000.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1002.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1006.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1007.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1009.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1013.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1016.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1019.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1021.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1025.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1026.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1027.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1041.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1055.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1058.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1062.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1064.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1066.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1074.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1075.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1080.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1083.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1085.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1088.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1111.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1112.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1116.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1118.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1119.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1126.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1131.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1138.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1139.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1142.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1146.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1155.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1157.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1164.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1170.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1177.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1180.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1181.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1191.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1194.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1195.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1196.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1197.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1198.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1199.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1203.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1208.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1213.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1216.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1217.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1218.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1222.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1232.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1236.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1238.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1247.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1256.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1260.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1263.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1264.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1265.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1266.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1269.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1270.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1271.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1279.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1280.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1287.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1300.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1303.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1311.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1313.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1316.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1323.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1328.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1333.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1338.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1344.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1348.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1349.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1361.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1362.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1365.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1369.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1371.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1375.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1377.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1379.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1380.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1387.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1389.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1390.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1392.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1395.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1397.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1399.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1400.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1407.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1408.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1413.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1414.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1415.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1420.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1421.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1422.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1423.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1430.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1432.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1433.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1435.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1436.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1437.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1440.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1447.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1452.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1457.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1459.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1461.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1465.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1471.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1472.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1473.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1474.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1476.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1478.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1480.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1494.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1498.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1499.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1504.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1509.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1513.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1521.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1523.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1524.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1539.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1542.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1544.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1558.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1565.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1582.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1583.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1584.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1594.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1628.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1638.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1647.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1652.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1663.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1664.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1679.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1686.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1698.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1708.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1711.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1712.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1718.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1719.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1722.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1742.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1744.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1746.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1767.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1780.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1793.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1794.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1798.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1804.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1813.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1827.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1830.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1834.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1849.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1852.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1857.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1864.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1870.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1871.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1881.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1882.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1891.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1892.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1894.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1897.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1914.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1916.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1933.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1941.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1946.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1954.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1958.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1963.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1984.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1988.json
#   inflating: ./dataPlanSDR/dataPlanSDR_1990.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2010.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2011.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2021.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2028.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2029.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2031.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2048.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2051.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2053.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2064.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2068.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2069.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2075.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2079.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2084.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2093.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2096.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2104.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2108.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2110.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2114.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2118.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2124.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2128.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2133.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2139.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2141.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2152.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2159.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2166.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2168.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2169.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2170.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2175.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2182.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2185.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2188.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2189.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2201.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2204.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2205.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2215.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2218.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2221.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2228.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2231.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2234.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2235.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2239.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2240.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2242.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2249.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2253.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2260.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2272.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2277.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2283.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2285.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2291.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2301.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2314.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2323.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2334.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2337.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2338.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2339.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2340.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2345.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2346.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2347.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2348.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2351.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2358.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2359.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2363.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2368.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2378.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2379.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2387.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2397.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2398.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2404.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2405.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2409.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2411.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2414.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2416.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2427.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2442.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2444.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2448.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2449.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2456.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2458.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2462.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2465.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2476.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2484.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2485.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2488.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2493.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2495.json
#   inflating: ./dataPlanSDR/dataPlanSDR_2497.json

# %%
df = pd.read_json("/content/dataPlanSDR/dataPlanSDR_0.json")

for i in range(1,2499):
  df = pd.concat([df, pd.read_json("/content/dataPlanSDR/dataPlanSDR_%s.json" % i)])
  print("Loaded File - dataPlanSDR_%s.json" % i)
# Out:
# Loaded File - dataPlanSDR_1.json
# Loaded File - dataPlanSDR_2.json
# Loaded File - dataPlanSDR_3.json
# Loaded File - dataPlanSDR_4.json
# Loaded File - dataPlanSDR_5.json
# Loaded File - dataPlanSDR_6.json
# Loaded File - dataPlanSDR_7.json
# Loaded File - dataPlanSDR_8.json
# Loaded File - dataPlanSDR_9.json
# Loaded File - dataPlanSDR_10.json
# Loaded File - dataPlanSDR_11.json
# Loaded File - dataPlanSDR_12.json
# Loaded File - dataPlanSDR_13.json
# Loaded File - dataPlanSDR_14.json
# Loaded File - dataPlanSDR_15.json
# Loaded File - dataPlanSDR_16.json
# Loaded File - dataPlanSDR_17.json
# Loaded File - dataPlanSDR_18.json
# Loaded File - dataPlanSDR_19.json
# Loaded File - dataPlanSDR_20.json
# Loaded File - dataPlanSDR_21.json
# Loaded File - dataPlanSDR_22.json
# Loaded File - dataPlanSDR_23.json
# Loaded File - dataPlanSDR_24.json
# Loaded File - dataPlanSDR_25.json
# Loaded File - dataPlanSDR_26.json
# Loaded File - dataPlanSDR_27.json
# Loaded File - dataPlanSDR_28.json
# Loaded File - dataPlanSDR_29.json
# Loaded File - dataPlanSDR_30.json
# Loaded File - dataPlanSDR_31.json
# Loaded File - dataPlanSDR_32.json
# Loaded File - dataPlanSDR_33.json
# Loaded File - dataPlanSDR_34.json
# Loaded File - dataPlanSDR_35.json
# Loaded File - dataPlanSDR_36.json
# Loaded File - dataPlanSDR_37.json
# Loaded File - dataPlanSDR_38.json
# Loaded File - dataPlanSDR_39.json
# Loaded File - dataPlanSDR_40.json
# Loaded File - dataPlanSDR_41.json
# Loaded File - dataPlanSDR_42.json
# Loaded File - dataPlanSDR_43.json
# Loaded File - dataPlanSDR_44.json
# Loaded File - dataPlanSDR_45.json
# Loaded File - dataPlanSDR_46.json
# Loaded File - dataPlanSDR_47.json
# Loaded File - dataPlanSDR_48.json
# Loaded File - dataPlanSDR_49.json
# Loaded File - dataPlanSDR_50.json
# Loaded File - dataPlanSDR_51.json
# Loaded File - dataPlanSDR_52.json
# Loaded File - dataPlanSDR_53.json
# Loaded File - dataPlanSDR_54.json
# Loaded File - dataPlanSDR_55.json
# Loaded File - dataPlanSDR_56.json
# Loaded File - dataPlanSDR_57.json
# Loaded File - dataPlanSDR_58.json
# Loaded File - dataPlanSDR_59.json
# Loaded File - dataPlanSDR_60.json
# Loaded File - dataPlanSDR_61.json
# Loaded File - dataPlanSDR_62.json
# Loaded File - dataPlanSDR_63.json
# Loaded File - dataPlanSDR_64.json
# Loaded File - dataPlanSDR_65.json
# Loaded File - dataPlanSDR_66.json
# Loaded File - dataPlanSDR_67.json
# Loaded File - dataPlanSDR_68.json
# Loaded File - dataPlanSDR_69.json
# Loaded File - dataPlanSDR_70.json
# Loaded File - dataPlanSDR_71.json
# Loaded File - dataPlanSDR_72.json
# Loaded File - dataPlanSDR_73.json
# Loaded File - dataPlanSDR_74.json
# Loaded File - dataPlanSDR_75.json
# Loaded File - dataPlanSDR_76.json
# Loaded File - dataPlanSDR_77.json
# Loaded File - dataPlanSDR_78.json
# Loaded File - dataPlanSDR_79.json
# Loaded File - dataPlanSDR_80.json
# Loaded File - dataPlanSDR_81.json
# Loaded File - dataPlanSDR_82.json
# Loaded File - dataPlanSDR_83.json
# Loaded File - dataPlanSDR_84.json
# Loaded File - dataPlanSDR_85.json
# Loaded File - dataPlanSDR_86.json
# Loaded File - dataPlanSDR_87.json
# Loaded File - dataPlanSDR_88.json
# Loaded File - dataPlanSDR_89.json
# Loaded File - dataPlanSDR_90.json
# Loaded File - dataPlanSDR_91.json
# Loaded File - dataPlanSDR_92.json
# Loaded File - dataPlanSDR_93.json
# Loaded File - dataPlanSDR_94.json
# Loaded File - dataPlanSDR_95.json
# Loaded File - dataPlanSDR_96.json
# Loaded File - dataPlanSDR_97.json
# Loaded File - dataPlanSDR_98.json
# Loaded File - dataPlanSDR_99.json
# Loaded File - dataPlanSDR_100.json
# Loaded File - dataPlanSDR_101.json
# Loaded File - dataPlanSDR_102.json
# Loaded File - dataPlanSDR_103.json
# Loaded File - dataPlanSDR_104.json
# Loaded File - dataPlanSDR_105.json
# Loaded File - dataPlanSDR_106.json
# Loaded File - dataPlanSDR_107.json
# Loaded File - dataPlanSDR_108.json
# Loaded File - dataPlanSDR_109.json
# Loaded File - dataPlanSDR_110.json
# Loaded File - dataPlanSDR_111.json
# Loaded File - dataPlanSDR_112.json
# Loaded File - dataPlanSDR_113.json
# Loaded File - dataPlanSDR_114.json
# Loaded File - dataPlanSDR_115.json
# Loaded File - dataPlanSDR_116.json
# Loaded File - dataPlanSDR_117.json
# Loaded File - dataPlanSDR_118.json
# Loaded File - dataPlanSDR_119.json
# Loaded File - dataPlanSDR_120.json
# Loaded File - dataPlanSDR_121.json
# Loaded File - dataPlanSDR_122.json
# Loaded File - dataPlanSDR_123.json
# Loaded File - dataPlanSDR_124.json
# Loaded File - dataPlanSDR_125.json
# Loaded File - dataPlanSDR_126.json
# Loaded File - dataPlanSDR_127.json
# Loaded File - dataPlanSDR_128.json
# Loaded File - dataPlanSDR_129.json
# Loaded File - dataPlanSDR_130.json
# Loaded File - dataPlanSDR_131.json
# Loaded File - dataPlanSDR_132.json
# Loaded File - dataPlanSDR_133.json
# Loaded File - dataPlanSDR_134.json
# Loaded File - dataPlanSDR_135.json
# Loaded File - dataPlanSDR_136.json
# Loaded File - dataPlanSDR_137.json
# Loaded File - dataPlanSDR_138.json
# Loaded File - dataPlanSDR_139.json
# Loaded File - dataPlanSDR_140.json
# Loaded File - dataPlanSDR_141.json
# Loaded File - dataPlanSDR_142.json
# Loaded File - dataPlanSDR_143.json
# Loaded File - dataPlanSDR_144.json
# Loaded File - dataPlanSDR_145.json
# Loaded File - dataPlanSDR_146.json
# Loaded File - dataPlanSDR_147.json
# Loaded File - dataPlanSDR_148.json
# Loaded File - dataPlanSDR_149.json
# Loaded File - dataPlanSDR_150.json
# Loaded File - dataPlanSDR_151.json
# Loaded File - dataPlanSDR_152.json
# Loaded File - dataPlanSDR_153.json
# Loaded File - dataPlanSDR_154.json
# Loaded File - dataPlanSDR_155.json
# Loaded File - dataPlanSDR_156.json
# Loaded File - dataPlanSDR_157.json
# Loaded File - dataPlanSDR_158.json
# Loaded File - dataPlanSDR_159.json
# Loaded File - dataPlanSDR_160.json
# Loaded File - dataPlanSDR_161.json
# Loaded File - dataPlanSDR_162.json
# Loaded File - dataPlanSDR_163.json
# Loaded File - dataPlanSDR_164.json
# Loaded File - dataPlanSDR_165.json
# Loaded File - dataPlanSDR_166.json
# Loaded File - dataPlanSDR_167.json
# Loaded File - dataPlanSDR_168.json
# Loaded File - dataPlanSDR_169.json
# Loaded File - dataPlanSDR_170.json
# Loaded File - dataPlanSDR_171.json
# Loaded File - dataPlanSDR_172.json
# Loaded File - dataPlanSDR_173.json
# Loaded File - dataPlanSDR_174.json
# Loaded File - dataPlanSDR_175.json
# Loaded File - dataPlanSDR_176.json
# Loaded File - dataPlanSDR_177.json
# Loaded File - dataPlanSDR_178.json
# Loaded File - dataPlanSDR_179.json
# Loaded File - dataPlanSDR_180.json
# Loaded File - dataPlanSDR_181.json
# Loaded File - dataPlanSDR_182.json
# Loaded File - dataPlanSDR_183.json
# Loaded File - dataPlanSDR_184.json
# Loaded File - dataPlanSDR_185.json
# Loaded File - dataPlanSDR_186.json
# Loaded File - dataPlanSDR_187.json
# Loaded File - dataPlanSDR_188.json
# Loaded File - dataPlanSDR_189.json
# Loaded File - dataPlanSDR_190.json
# Loaded File - dataPlanSDR_191.json
# Loaded File - dataPlanSDR_192.json
# Loaded File - dataPlanSDR_193.json
# Loaded File - dataPlanSDR_194.json
# Loaded File - dataPlanSDR_195.json
# Loaded File - dataPlanSDR_196.json
# Loaded File - dataPlanSDR_197.json
# Loaded File - dataPlanSDR_198.json
# Loaded File - dataPlanSDR_199.json
# Loaded File - dataPlanSDR_200.json
# Loaded File - dataPlanSDR_201.json
# Loaded File - dataPlanSDR_202.json
# Loaded File - dataPlanSDR_203.json
# Loaded File - dataPlanSDR_204.json
# Loaded File - dataPlanSDR_205.json
# Loaded File - dataPlanSDR_206.json
# Loaded File - dataPlanSDR_207.json
# Loaded File - dataPlanSDR_208.json
# Loaded File - dataPlanSDR_209.json
# Loaded File - dataPlanSDR_210.json
# Loaded File - dataPlanSDR_211.json
# Loaded File - dataPlanSDR_212.json
# Loaded File - dataPlanSDR_213.json
# Loaded File - dataPlanSDR_214.json
# Loaded File - dataPlanSDR_215.json
# Loaded File - dataPlanSDR_216.json
# Loaded File - dataPlanSDR_217.json
# Loaded File - dataPlanSDR_218.json
# Loaded File - dataPlanSDR_219.json
# Loaded File - dataPlanSDR_220.json
# Loaded File - dataPlanSDR_221.json
# Loaded File - dataPlanSDR_222.json
# Loaded File - dataPlanSDR_223.json
# Loaded File - dataPlanSDR_224.json
# Loaded File - dataPlanSDR_225.json
# Loaded File - dataPlanSDR_226.json
# Loaded File - dataPlanSDR_227.json
# Loaded File - dataPlanSDR_228.json
# Loaded File - dataPlanSDR_229.json
# Loaded File - dataPlanSDR_230.json
# Loaded File - dataPlanSDR_231.json
# Loaded File - dataPlanSDR_232.json
# Loaded File - dataPlanSDR_233.json
# Loaded File - dataPlanSDR_234.json
# Loaded File - dataPlanSDR_235.json
# Loaded File - dataPlanSDR_236.json
# Loaded File - dataPlanSDR_237.json
# Loaded File - dataPlanSDR_238.json
# Loaded File - dataPlanSDR_239.json
# Loaded File - dataPlanSDR_240.json
# Loaded File - dataPlanSDR_241.json
# Loaded File - dataPlanSDR_242.json
# Loaded File - dataPlanSDR_243.json
# Loaded File - dataPlanSDR_244.json
# Loaded File - dataPlanSDR_245.json
# Loaded File - dataPlanSDR_246.json
# Loaded File - dataPlanSDR_247.json
# Loaded File - dataPlanSDR_248.json
# Loaded File - dataPlanSDR_249.json
# Loaded File - dataPlanSDR_250.json
# Loaded File - dataPlanSDR_251.json
# Loaded File - dataPlanSDR_252.json
# Loaded File - dataPlanSDR_253.json
# Loaded File - dataPlanSDR_254.json
# Loaded File - dataPlanSDR_255.json
# Loaded File - dataPlanSDR_256.json
# Loaded File - dataPlanSDR_257.json
# Loaded File - dataPlanSDR_258.json
# Loaded File - dataPlanSDR_259.json
# Loaded File - dataPlanSDR_260.json
# Loaded File - dataPlanSDR_261.json
# Loaded File - dataPlanSDR_262.json
# Loaded File - dataPlanSDR_263.json
# Loaded File - dataPlanSDR_264.json
# Loaded File - dataPlanSDR_265.json
# Loaded File - dataPlanSDR_266.json
# Loaded File - dataPlanSDR_267.json
# Loaded File - dataPlanSDR_268.json
# Loaded File - dataPlanSDR_269.json
# Loaded File - dataPlanSDR_270.json
# Loaded File - dataPlanSDR_271.json
# Loaded File - dataPlanSDR_272.json
# Loaded File - dataPlanSDR_273.json
# Loaded File - dataPlanSDR_274.json
# Loaded File - dataPlanSDR_275.json
# Loaded File - dataPlanSDR_276.json
# Loaded File - dataPlanSDR_277.json
# Loaded File - dataPlanSDR_278.json
# Loaded File - dataPlanSDR_279.json
# Loaded File - dataPlanSDR_280.json
# Loaded File - dataPlanSDR_281.json
# Loaded File - dataPlanSDR_282.json
# Loaded File - dataPlanSDR_283.json
# Loaded File - dataPlanSDR_284.json
# Loaded File - dataPlanSDR_285.json
# Loaded File - dataPlanSDR_286.json
# Loaded File - dataPlanSDR_287.json
# Loaded File - dataPlanSDR_288.json
# Loaded File - dataPlanSDR_289.json
# Loaded File - dataPlanSDR_290.json
# Loaded File - dataPlanSDR_291.json
# Loaded File - dataPlanSDR_292.json
# Loaded File - dataPlanSDR_293.json
# Loaded File - dataPlanSDR_294.json
# Loaded File - dataPlanSDR_295.json
# Loaded File - dataPlanSDR_296.json
# Loaded File - dataPlanSDR_297.json
# Loaded File - dataPlanSDR_298.json
# Loaded File - dataPlanSDR_299.json
# Loaded File - dataPlanSDR_300.json
# Loaded File - dataPlanSDR_301.json
# Loaded File - dataPlanSDR_302.json
# Loaded File - dataPlanSDR_303.json
# Loaded File - dataPlanSDR_304.json
# Loaded File - dataPlanSDR_305.json
# Loaded File - dataPlanSDR_306.json
# Loaded File - dataPlanSDR_307.json
# Loaded File - dataPlanSDR_308.json
# Loaded File - dataPlanSDR_309.json
# Loaded File - dataPlanSDR_310.json
# Loaded File - dataPlanSDR_311.json
# Loaded File - dataPlanSDR_312.json
# Loaded File - dataPlanSDR_313.json
# Loaded File - dataPlanSDR_314.json
# Loaded File - dataPlanSDR_315.json
# Loaded File - dataPlanSDR_316.json
# Loaded File - dataPlanSDR_317.json
# Loaded File - dataPlanSDR_318.json
# Loaded File - dataPlanSDR_319.json
# Loaded File - dataPlanSDR_320.json
# Loaded File - dataPlanSDR_321.json
# Loaded File - dataPlanSDR_322.json
# Loaded File - dataPlanSDR_323.json
# Loaded File - dataPlanSDR_324.json
# Loaded File - dataPlanSDR_325.json
# Loaded File - dataPlanSDR_326.json
# Loaded File - dataPlanSDR_327.json
# Loaded File - dataPlanSDR_328.json
# Loaded File - dataPlanSDR_329.json
# Loaded File - dataPlanSDR_330.json
# Loaded File - dataPlanSDR_331.json
# Loaded File - dataPlanSDR_332.json
# Loaded File - dataPlanSDR_333.json
# Loaded File - dataPlanSDR_334.json
# Loaded File - dataPlanSDR_335.json
# Loaded File - dataPlanSDR_336.json
# Loaded File - dataPlanSDR_337.json
# Loaded File - dataPlanSDR_338.json
# Loaded File - dataPlanSDR_339.json
# Loaded File - dataPlanSDR_340.json
# Loaded File - dataPlanSDR_341.json
# Loaded File - dataPlanSDR_342.json
# Loaded File - dataPlanSDR_343.json
# Loaded File - dataPlanSDR_344.json
# Loaded File - dataPlanSDR_345.json
# Loaded File - dataPlanSDR_346.json
# Loaded File - dataPlanSDR_347.json
# Loaded File - dataPlanSDR_348.json
# Loaded File - dataPlanSDR_349.json
# Loaded File - dataPlanSDR_350.json
# Loaded File - dataPlanSDR_351.json
# Loaded File - dataPlanSDR_352.json
# Loaded File - dataPlanSDR_353.json
# Loaded File - dataPlanSDR_354.json
# Loaded File - dataPlanSDR_355.json
# Loaded File - dataPlanSDR_356.json
# Loaded File - dataPlanSDR_357.json
# Loaded File - dataPlanSDR_358.json
# Loaded File - dataPlanSDR_359.json
# Loaded File - dataPlanSDR_360.json
# Loaded File - dataPlanSDR_361.json
# Loaded File - dataPlanSDR_362.json
# Loaded File - dataPlanSDR_363.json
# Loaded File - dataPlanSDR_364.json
# Loaded File - dataPlanSDR_365.json
# Loaded File - dataPlanSDR_366.json
# Loaded File - dataPlanSDR_367.json
# Loaded File - dataPlanSDR_368.json
# Loaded File - dataPlanSDR_369.json
# Loaded File - dataPlanSDR_370.json
# Loaded File - dataPlanSDR_371.json
# Loaded File - dataPlanSDR_372.json
# Loaded File - dataPlanSDR_373.json
# Loaded File - dataPlanSDR_374.json
# Loaded File - dataPlanSDR_375.json
# Loaded File - dataPlanSDR_376.json
# Loaded File - dataPlanSDR_377.json
# Loaded File - dataPlanSDR_378.json
# Loaded File - dataPlanSDR_379.json
# Loaded File - dataPlanSDR_380.json
# Loaded File - dataPlanSDR_381.json
# Loaded File - dataPlanSDR_382.json
# Loaded File - dataPlanSDR_383.json
# Loaded File - dataPlanSDR_384.json
# Loaded File - dataPlanSDR_385.json
# Loaded File - dataPlanSDR_386.json
# Loaded File - dataPlanSDR_387.json
# Loaded File - dataPlanSDR_388.json
# Loaded File - dataPlanSDR_389.json
# Loaded File - dataPlanSDR_390.json
# Loaded File - dataPlanSDR_391.json
# Loaded File - dataPlanSDR_392.json
# Loaded File - dataPlanSDR_393.json
# Loaded File - dataPlanSDR_394.json
# Loaded File - dataPlanSDR_395.json
# Loaded File - dataPlanSDR_396.json
# Loaded File - dataPlanSDR_397.json
# Loaded File - dataPlanSDR_398.json
# Loaded File - dataPlanSDR_399.json
# Loaded File - dataPlanSDR_400.json
# Loaded File - dataPlanSDR_401.json
# Loaded File - dataPlanSDR_402.json
# Loaded File - dataPlanSDR_403.json
# Loaded File - dataPlanSDR_404.json
# Loaded File - dataPlanSDR_405.json
# Loaded File - dataPlanSDR_406.json
# Loaded File - dataPlanSDR_407.json
# Loaded File - dataPlanSDR_408.json
# Loaded File - dataPlanSDR_409.json
# Loaded File - dataPlanSDR_410.json
# Loaded File - dataPlanSDR_411.json
# Loaded File - dataPlanSDR_412.json
# Loaded File - dataPlanSDR_413.json
# Loaded File - dataPlanSDR_414.json
# Loaded File - dataPlanSDR_415.json
# Loaded File - dataPlanSDR_416.json
# Loaded File - dataPlanSDR_417.json
# Loaded File - dataPlanSDR_418.json
# Loaded File - dataPlanSDR_419.json
# Loaded File - dataPlanSDR_420.json
# Loaded File - dataPlanSDR_421.json
# Loaded File - dataPlanSDR_422.json
# Loaded File - dataPlanSDR_423.json
# Loaded File - dataPlanSDR_424.json
# Loaded File - dataPlanSDR_425.json
# Loaded File - dataPlanSDR_426.json
# Loaded File - dataPlanSDR_427.json
# Loaded File - dataPlanSDR_428.json
# Loaded File - dataPlanSDR_429.json
# Loaded File - dataPlanSDR_430.json
# Loaded File - dataPlanSDR_431.json
# Loaded File - dataPlanSDR_432.json
# Loaded File - dataPlanSDR_433.json
# Loaded File - dataPlanSDR_434.json
# Loaded File - dataPlanSDR_435.json
# Loaded File - dataPlanSDR_436.json
# Loaded File - dataPlanSDR_437.json
# Loaded File - dataPlanSDR_438.json
# Loaded File - dataPlanSDR_439.json
# Loaded File - dataPlanSDR_440.json
# Loaded File - dataPlanSDR_441.json
# Loaded File - dataPlanSDR_442.json
# Loaded File - dataPlanSDR_443.json
# Loaded File - dataPlanSDR_444.json
# Loaded File - dataPlanSDR_445.json
# Loaded File - dataPlanSDR_446.json
# Loaded File - dataPlanSDR_447.json
# Loaded File - dataPlanSDR_448.json
# Loaded File - dataPlanSDR_449.json
# Loaded File - dataPlanSDR_450.json
# Loaded File - dataPlanSDR_451.json
# Loaded File - dataPlanSDR_452.json
# Loaded File - dataPlanSDR_453.json
# Loaded File - dataPlanSDR_454.json
# Loaded File - dataPlanSDR_455.json
# Loaded File - dataPlanSDR_456.json
# Loaded File - dataPlanSDR_457.json
# Loaded File - dataPlanSDR_458.json
# Loaded File - dataPlanSDR_459.json
# Loaded File - dataPlanSDR_460.json
# Loaded File - dataPlanSDR_461.json
# Loaded File - dataPlanSDR_462.json
# Loaded File - dataPlanSDR_463.json
# Loaded File - dataPlanSDR_464.json
# Loaded File - dataPlanSDR_465.json
# Loaded File - dataPlanSDR_466.json
# Loaded File - dataPlanSDR_467.json
# Loaded File - dataPlanSDR_468.json
# Loaded File - dataPlanSDR_469.json
# Loaded File - dataPlanSDR_470.json
# Loaded File - dataPlanSDR_471.json
# Loaded File - dataPlanSDR_472.json
# Loaded File - dataPlanSDR_473.json
# Loaded File - dataPlanSDR_474.json
# Loaded File - dataPlanSDR_475.json
# Loaded File - dataPlanSDR_476.json
# Loaded File - dataPlanSDR_477.json
# Loaded File - dataPlanSDR_478.json
# Loaded File - dataPlanSDR_479.json
# Loaded File - dataPlanSDR_480.json
# Loaded File - dataPlanSDR_481.json
# Loaded File - dataPlanSDR_482.json
# Loaded File - dataPlanSDR_483.json
# Loaded File - dataPlanSDR_484.json
# Loaded File - dataPlanSDR_485.json
# Loaded File - dataPlanSDR_486.json
# Loaded File - dataPlanSDR_487.json
# Loaded File - dataPlanSDR_488.json
# Loaded File - dataPlanSDR_489.json
# Loaded File - dataPlanSDR_490.json
# Loaded File - dataPlanSDR_491.json
# Loaded File - dataPlanSDR_492.json
# Loaded File - dataPlanSDR_493.json
# Loaded File - dataPlanSDR_494.json
# Loaded File - dataPlanSDR_495.json
# Loaded File - dataPlanSDR_496.json
# Loaded File - dataPlanSDR_497.json
# Loaded File - dataPlanSDR_498.json
# Loaded File - dataPlanSDR_499.json
# Loaded File - dataPlanSDR_500.json
# Loaded File - dataPlanSDR_501.json
# Loaded File - dataPlanSDR_502.json
# Loaded File - dataPlanSDR_503.json
# Loaded File - dataPlanSDR_504.json
# Loaded File - dataPlanSDR_505.json
# Loaded File - dataPlanSDR_506.json
# Loaded File - dataPlanSDR_507.json
# Loaded File - dataPlanSDR_508.json
# Loaded File - dataPlanSDR_509.json
# Loaded File - dataPlanSDR_510.json
# Loaded File - dataPlanSDR_511.json
# Loaded File - dataPlanSDR_512.json
# Loaded File - dataPlanSDR_513.json
# Loaded File - dataPlanSDR_514.json
# Loaded File - dataPlanSDR_515.json
# Loaded File - dataPlanSDR_516.json
# Loaded File - dataPlanSDR_517.json
# Loaded File - dataPlanSDR_518.json
# Loaded File - dataPlanSDR_519.json
# Loaded File - dataPlanSDR_520.json
# Loaded File - dataPlanSDR_521.json
# Loaded File - dataPlanSDR_522.json
# Loaded File - dataPlanSDR_523.json
# Loaded File - dataPlanSDR_524.json
# Loaded File - dataPlanSDR_525.json
# Loaded File - dataPlanSDR_526.json
# Loaded File - dataPlanSDR_527.json
# Loaded File - dataPlanSDR_528.json
# Loaded File - dataPlanSDR_529.json
# Loaded File - dataPlanSDR_530.json
# Loaded File - dataPlanSDR_531.json
# Loaded File - dataPlanSDR_532.json
# Loaded File - dataPlanSDR_533.json
# Loaded File - dataPlanSDR_534.json
# Loaded File - dataPlanSDR_535.json
# Loaded File - dataPlanSDR_536.json
# Loaded File - dataPlanSDR_537.json
# Loaded File - dataPlanSDR_538.json
# Loaded File - dataPlanSDR_539.json
# Loaded File - dataPlanSDR_540.json
# Loaded File - dataPlanSDR_541.json
# Loaded File - dataPlanSDR_542.json
# Loaded File - dataPlanSDR_543.json
# Loaded File - dataPlanSDR_544.json
# Loaded File - dataPlanSDR_545.json
# Loaded File - dataPlanSDR_546.json
# Loaded File - dataPlanSDR_547.json
# Loaded File - dataPlanSDR_548.json
# Loaded File - dataPlanSDR_549.json
# Loaded File - dataPlanSDR_550.json
# Loaded File - dataPlanSDR_551.json
# Loaded File - dataPlanSDR_552.json
# Loaded File - dataPlanSDR_553.json
# Loaded File - dataPlanSDR_554.json
# Loaded File - dataPlanSDR_555.json
# Loaded File - dataPlanSDR_556.json
# Loaded File - dataPlanSDR_557.json
# Loaded File - dataPlanSDR_558.json
# Loaded File - dataPlanSDR_559.json
# Loaded File - dataPlanSDR_560.json
# Loaded File - dataPlanSDR_561.json
# Loaded File - dataPlanSDR_562.json
# Loaded File - dataPlanSDR_563.json
# Loaded File - dataPlanSDR_564.json
# Loaded File - dataPlanSDR_565.json
# Loaded File - dataPlanSDR_566.json
# Loaded File - dataPlanSDR_567.json
# Loaded File - dataPlanSDR_568.json
# Loaded File - dataPlanSDR_569.json
# Loaded File - dataPlanSDR_570.json
# Loaded File - dataPlanSDR_571.json
# Loaded File - dataPlanSDR_572.json
# Loaded File - dataPlanSDR_573.json
# Loaded File - dataPlanSDR_574.json
# Loaded File - dataPlanSDR_575.json
# Loaded File - dataPlanSDR_576.json
# Loaded File - dataPlanSDR_577.json
# Loaded File - dataPlanSDR_578.json
# Loaded File - dataPlanSDR_579.json
# Loaded File - dataPlanSDR_580.json
# Loaded File - dataPlanSDR_581.json
# Loaded File - dataPlanSDR_582.json
# Loaded File - dataPlanSDR_583.json
# Loaded File - dataPlanSDR_584.json
# Loaded File - dataPlanSDR_585.json
# Loaded File - dataPlanSDR_586.json
# Loaded File - dataPlanSDR_587.json
# Loaded File - dataPlanSDR_588.json
# Loaded File - dataPlanSDR_589.json
# Loaded File - dataPlanSDR_590.json
# Loaded File - dataPlanSDR_591.json
# Loaded File - dataPlanSDR_592.json
# Loaded File - dataPlanSDR_593.json
# Loaded File - dataPlanSDR_594.json
# Loaded File - dataPlanSDR_595.json
# Loaded File - dataPlanSDR_596.json
# Loaded File - dataPlanSDR_597.json
# Loaded File - dataPlanSDR_598.json
# Loaded File - dataPlanSDR_599.json
# Loaded File - dataPlanSDR_600.json
# Loaded File - dataPlanSDR_601.json
# Loaded File - dataPlanSDR_602.json
# Loaded File - dataPlanSDR_603.json
# Loaded File - dataPlanSDR_604.json
# Loaded File - dataPlanSDR_605.json
# Loaded File - dataPlanSDR_606.json
# Loaded File - dataPlanSDR_607.json
# Loaded File - dataPlanSDR_608.json
# Loaded File - dataPlanSDR_609.json
# Loaded File - dataPlanSDR_610.json
# Loaded File - dataPlanSDR_611.json
# Loaded File - dataPlanSDR_612.json
# Loaded File - dataPlanSDR_613.json
# Loaded File - dataPlanSDR_614.json
# Loaded File - dataPlanSDR_615.json
# Loaded File - dataPlanSDR_616.json
# Loaded File - dataPlanSDR_617.json
# Loaded File - dataPlanSDR_618.json
# Loaded File - dataPlanSDR_619.json
# Loaded File - dataPlanSDR_620.json
# Loaded File - dataPlanSDR_621.json
# Loaded File - dataPlanSDR_622.json
# Loaded File - dataPlanSDR_623.json
# Loaded File - dataPlanSDR_624.json
# Loaded File - dataPlanSDR_625.json
# Loaded File - dataPlanSDR_626.json
# Loaded File - dataPlanSDR_627.json
# Loaded File - dataPlanSDR_628.json
# Loaded File - dataPlanSDR_629.json
# Loaded File - dataPlanSDR_630.json
# Loaded File - dataPlanSDR_631.json
# Loaded File - dataPlanSDR_632.json
# Loaded File - dataPlanSDR_633.json
# Loaded File - dataPlanSDR_634.json
# Loaded File - dataPlanSDR_635.json
# Loaded File - dataPlanSDR_636.json
# Loaded File - dataPlanSDR_637.json
# Loaded File - dataPlanSDR_638.json
# Loaded File - dataPlanSDR_639.json
# Loaded File - dataPlanSDR_640.json
# Loaded File - dataPlanSDR_641.json
# Loaded File - dataPlanSDR_642.json
# Loaded File - dataPlanSDR_643.json
# Loaded File - dataPlanSDR_644.json
# Loaded File - dataPlanSDR_645.json
# Loaded File - dataPlanSDR_646.json
# Loaded File - dataPlanSDR_647.json
# Loaded File - dataPlanSDR_648.json
# Loaded File - dataPlanSDR_649.json
# Loaded File - dataPlanSDR_650.json
# Loaded File - dataPlanSDR_651.json
# Loaded File - dataPlanSDR_652.json
# Loaded File - dataPlanSDR_653.json
# Loaded File - dataPlanSDR_654.json
# Loaded File - dataPlanSDR_655.json
# Loaded File - dataPlanSDR_656.json
# Loaded File - dataPlanSDR_657.json
# Loaded File - dataPlanSDR_658.json
# Loaded File - dataPlanSDR_659.json
# Loaded File - dataPlanSDR_660.json
# Loaded File - dataPlanSDR_661.json
# Loaded File - dataPlanSDR_662.json
# Loaded File - dataPlanSDR_663.json
# Loaded File - dataPlanSDR_664.json
# Loaded File - dataPlanSDR_665.json
# Loaded File - dataPlanSDR_666.json
# Loaded File - dataPlanSDR_667.json
# Loaded File - dataPlanSDR_668.json
# Loaded File - dataPlanSDR_669.json
# Loaded File - dataPlanSDR_670.json
# Loaded File - dataPlanSDR_671.json
# Loaded File - dataPlanSDR_672.json
# Loaded File - dataPlanSDR_673.json
# Loaded File - dataPlanSDR_674.json
# Loaded File - dataPlanSDR_675.json
# Loaded File - dataPlanSDR_676.json
# Loaded File - dataPlanSDR_677.json
# Loaded File - dataPlanSDR_678.json
# Loaded File - dataPlanSDR_679.json
# Loaded File - dataPlanSDR_680.json
# Loaded File - dataPlanSDR_681.json
# Loaded File - dataPlanSDR_682.json
# Loaded File - dataPlanSDR_683.json
# Loaded File - dataPlanSDR_684.json
# Loaded File - dataPlanSDR_685.json
# Loaded File - dataPlanSDR_686.json
# Loaded File - dataPlanSDR_687.json
# Loaded File - dataPlanSDR_688.json
# Loaded File - dataPlanSDR_689.json
# Loaded File - dataPlanSDR_690.json
# Loaded File - dataPlanSDR_691.json
# Loaded File - dataPlanSDR_692.json
# Loaded File - dataPlanSDR_693.json
# Loaded File - dataPlanSDR_694.json
# Loaded File - dataPlanSDR_695.json
# Loaded File - dataPlanSDR_696.json
# Loaded File - dataPlanSDR_697.json
# Loaded File - dataPlanSDR_698.json
# Loaded File - dataPlanSDR_699.json
# Loaded File - dataPlanSDR_700.json
# Loaded File - dataPlanSDR_701.json
# Loaded File - dataPlanSDR_702.json
# Loaded File - dataPlanSDR_703.json
# Loaded File - dataPlanSDR_704.json
# Loaded File - dataPlanSDR_705.json
# Loaded File - dataPlanSDR_706.json
# Loaded File - dataPlanSDR_707.json
# Loaded File - dataPlanSDR_708.json
# Loaded File - dataPlanSDR_709.json
# Loaded File - dataPlanSDR_710.json
# Loaded File - dataPlanSDR_711.json
# Loaded File - dataPlanSDR_712.json
# Loaded File - dataPlanSDR_713.json
# Loaded File - dataPlanSDR_714.json
# Loaded File - dataPlanSDR_715.json
# Loaded File - dataPlanSDR_716.json
# Loaded File - dataPlanSDR_717.json
# Loaded File - dataPlanSDR_718.json
# Loaded File - dataPlanSDR_719.json
# Loaded File - dataPlanSDR_720.json
# Loaded File - dataPlanSDR_721.json
# Loaded File - dataPlanSDR_722.json
# Loaded File - dataPlanSDR_723.json
# Loaded File - dataPlanSDR_724.json
# Loaded File - dataPlanSDR_725.json
# Loaded File - dataPlanSDR_726.json
# Loaded File - dataPlanSDR_727.json
# Loaded File - dataPlanSDR_728.json
# Loaded File - dataPlanSDR_729.json
# Loaded File - dataPlanSDR_730.json
# Loaded File - dataPlanSDR_731.json
# Loaded File - dataPlanSDR_732.json
# Loaded File - dataPlanSDR_733.json
# Loaded File - dataPlanSDR_734.json
# Loaded File - dataPlanSDR_735.json
# Loaded File - dataPlanSDR_736.json
# Loaded File - dataPlanSDR_737.json
# Loaded File - dataPlanSDR_738.json
# Loaded File - dataPlanSDR_739.json
# Loaded File - dataPlanSDR_740.json
# Loaded File - dataPlanSDR_741.json
# Loaded File - dataPlanSDR_742.json
# Loaded File - dataPlanSDR_743.json
# Loaded File - dataPlanSDR_744.json
# Loaded File - dataPlanSDR_745.json
# Loaded File - dataPlanSDR_746.json
# Loaded File - dataPlanSDR_747.json
# Loaded File - dataPlanSDR_748.json
# Loaded File - dataPlanSDR_749.json
# Loaded File - dataPlanSDR_750.json
# Loaded File - dataPlanSDR_751.json
# Loaded File - dataPlanSDR_752.json
# Loaded File - dataPlanSDR_753.json
# Loaded File - dataPlanSDR_754.json
# Loaded File - dataPlanSDR_755.json
# Loaded File - dataPlanSDR_756.json
# Loaded File - dataPlanSDR_757.json
# Loaded File - dataPlanSDR_758.json
# Loaded File - dataPlanSDR_759.json
# Loaded File - dataPlanSDR_760.json
# Loaded File - dataPlanSDR_761.json
# Loaded File - dataPlanSDR_762.json
# Loaded File - dataPlanSDR_763.json
# Loaded File - dataPlanSDR_764.json
# Loaded File - dataPlanSDR_765.json
# Loaded File - dataPlanSDR_766.json
# Loaded File - dataPlanSDR_767.json
# Loaded File - dataPlanSDR_768.json
# Loaded File - dataPlanSDR_769.json
# Loaded File - dataPlanSDR_770.json
# Loaded File - dataPlanSDR_771.json
# Loaded File - dataPlanSDR_772.json
# Loaded File - dataPlanSDR_773.json
# Loaded File - dataPlanSDR_774.json
# Loaded File - dataPlanSDR_775.json
# Loaded File - dataPlanSDR_776.json
# Loaded File - dataPlanSDR_777.json
# Loaded File - dataPlanSDR_778.json
# Loaded File - dataPlanSDR_779.json
# Loaded File - dataPlanSDR_780.json
# Loaded File - dataPlanSDR_781.json
# Loaded File - dataPlanSDR_782.json
# Loaded File - dataPlanSDR_783.json
# Loaded File - dataPlanSDR_784.json
# Loaded File - dataPlanSDR_785.json
# Loaded File - dataPlanSDR_786.json
# Loaded File - dataPlanSDR_787.json
# Loaded File - dataPlanSDR_788.json
# Loaded File - dataPlanSDR_789.json
# Loaded File - dataPlanSDR_790.json
# Loaded File - dataPlanSDR_791.json
# Loaded File - dataPlanSDR_792.json
# Loaded File - dataPlanSDR_793.json
# Loaded File - dataPlanSDR_794.json
# Loaded File - dataPlanSDR_795.json
# Loaded File - dataPlanSDR_796.json
# Loaded File - dataPlanSDR_797.json
# Loaded File - dataPlanSDR_798.json
# Loaded File - dataPlanSDR_799.json
# Loaded File - dataPlanSDR_800.json
# Loaded File - dataPlanSDR_801.json
# Loaded File - dataPlanSDR_802.json
# Loaded File - dataPlanSDR_803.json
# Loaded File - dataPlanSDR_804.json
# Loaded File - dataPlanSDR_805.json
# Loaded File - dataPlanSDR_806.json
# Loaded File - dataPlanSDR_807.json
# Loaded File - dataPlanSDR_808.json
# Loaded File - dataPlanSDR_809.json
# Loaded File - dataPlanSDR_810.json
# Loaded File - dataPlanSDR_811.json
# Loaded File - dataPlanSDR_812.json
# Loaded File - dataPlanSDR_813.json
# Loaded File - dataPlanSDR_814.json
# Loaded File - dataPlanSDR_815.json
# Loaded File - dataPlanSDR_816.json
# Loaded File - dataPlanSDR_817.json
# Loaded File - dataPlanSDR_818.json
# Loaded File - dataPlanSDR_819.json
# Loaded File - dataPlanSDR_820.json
# Loaded File - dataPlanSDR_821.json
# Loaded File - dataPlanSDR_822.json
# Loaded File - dataPlanSDR_823.json
# Loaded File - dataPlanSDR_824.json
# Loaded File - dataPlanSDR_825.json
# Loaded File - dataPlanSDR_826.json
# Loaded File - dataPlanSDR_827.json
# Loaded File - dataPlanSDR_828.json
# Loaded File - dataPlanSDR_829.json
# Loaded File - dataPlanSDR_830.json
# Loaded File - dataPlanSDR_831.json
# Loaded File - dataPlanSDR_832.json
# Loaded File - dataPlanSDR_833.json
# Loaded File - dataPlanSDR_834.json
# Loaded File - dataPlanSDR_835.json
# Loaded File - dataPlanSDR_836.json
# Loaded File - dataPlanSDR_837.json
# Loaded File - dataPlanSDR_838.json
# Loaded File - dataPlanSDR_839.json
# Loaded File - dataPlanSDR_840.json
# Loaded File - dataPlanSDR_841.json
# Loaded File - dataPlanSDR_842.json
# Loaded File - dataPlanSDR_843.json
# Loaded File - dataPlanSDR_844.json
# Loaded File - dataPlanSDR_845.json
# Loaded File - dataPlanSDR_846.json
# Loaded File - dataPlanSDR_847.json
# Loaded File - dataPlanSDR_848.json
# Loaded File - dataPlanSDR_849.json
# Loaded File - dataPlanSDR_850.json
# Loaded File - dataPlanSDR_851.json
# Loaded File - dataPlanSDR_852.json
# Loaded File - dataPlanSDR_853.json
# Loaded File - dataPlanSDR_854.json
# Loaded File - dataPlanSDR_855.json
# Loaded File - dataPlanSDR_856.json
# Loaded File - dataPlanSDR_857.json
# Loaded File - dataPlanSDR_858.json
# Loaded File - dataPlanSDR_859.json
# Loaded File - dataPlanSDR_860.json
# Loaded File - dataPlanSDR_861.json
# Loaded File - dataPlanSDR_862.json
# Loaded File - dataPlanSDR_863.json
# Loaded File - dataPlanSDR_864.json
# Loaded File - dataPlanSDR_865.json
# Loaded File - dataPlanSDR_866.json
# Loaded File - dataPlanSDR_867.json
# Loaded File - dataPlanSDR_868.json
# Loaded File - dataPlanSDR_869.json
# Loaded File - dataPlanSDR_870.json
# Loaded File - dataPlanSDR_871.json
# Loaded File - dataPlanSDR_872.json
# Loaded File - dataPlanSDR_873.json
# Loaded File - dataPlanSDR_874.json
# Loaded File - dataPlanSDR_875.json
# Loaded File - dataPlanSDR_876.json
# Loaded File - dataPlanSDR_877.json
# Loaded File - dataPlanSDR_878.json
# Loaded File - dataPlanSDR_879.json
# Loaded File - dataPlanSDR_880.json
# Loaded File - dataPlanSDR_881.json
# Loaded File - dataPlanSDR_882.json
# Loaded File - dataPlanSDR_883.json
# Loaded File - dataPlanSDR_884.json
# Loaded File - dataPlanSDR_885.json
# Loaded File - dataPlanSDR_886.json
# Loaded File - dataPlanSDR_887.json
# Loaded File - dataPlanSDR_888.json
# Loaded File - dataPlanSDR_889.json
# Loaded File - dataPlanSDR_890.json
# Loaded File - dataPlanSDR_891.json
# Loaded File - dataPlanSDR_892.json
# Loaded File - dataPlanSDR_893.json
# Loaded File - dataPlanSDR_894.json
# Loaded File - dataPlanSDR_895.json
# Loaded File - dataPlanSDR_896.json
# Loaded File - dataPlanSDR_897.json
# Loaded File - dataPlanSDR_898.json
# Loaded File - dataPlanSDR_899.json
# Loaded File - dataPlanSDR_900.json
# Loaded File - dataPlanSDR_901.json
# Loaded File - dataPlanSDR_902.json
# Loaded File - dataPlanSDR_903.json
# Loaded File - dataPlanSDR_904.json
# Loaded File - dataPlanSDR_905.json
# Loaded File - dataPlanSDR_906.json
# Loaded File - dataPlanSDR_907.json
# Loaded File - dataPlanSDR_908.json
# Loaded File - dataPlanSDR_909.json
# Loaded File - dataPlanSDR_910.json
# Loaded File - dataPlanSDR_911.json
# Loaded File - dataPlanSDR_912.json
# Loaded File - dataPlanSDR_913.json
# Loaded File - dataPlanSDR_914.json
# Loaded File - dataPlanSDR_915.json
# Loaded File - dataPlanSDR_916.json
# Loaded File - dataPlanSDR_917.json
# Loaded File - dataPlanSDR_918.json
# Loaded File - dataPlanSDR_919.json
# Loaded File - dataPlanSDR_920.json
# Loaded File - dataPlanSDR_921.json
# Loaded File - dataPlanSDR_922.json
# Loaded File - dataPlanSDR_923.json
# Loaded File - dataPlanSDR_924.json
# Loaded File - dataPlanSDR_925.json
# Loaded File - dataPlanSDR_926.json
# Loaded File - dataPlanSDR_927.json
# Loaded File - dataPlanSDR_928.json
# Loaded File - dataPlanSDR_929.json
# Loaded File - dataPlanSDR_930.json
# Loaded File - dataPlanSDR_931.json
# Loaded File - dataPlanSDR_932.json
# Loaded File - dataPlanSDR_933.json
# Loaded File - dataPlanSDR_934.json
# Loaded File - dataPlanSDR_935.json
# Loaded File - dataPlanSDR_936.json
# Loaded File - dataPlanSDR_937.json
# Loaded File - dataPlanSDR_938.json
# Loaded File - dataPlanSDR_939.json
# Loaded File - dataPlanSDR_940.json
# Loaded File - dataPlanSDR_941.json
# Loaded File - dataPlanSDR_942.json
# Loaded File - dataPlanSDR_943.json
# Loaded File - dataPlanSDR_944.json
# Loaded File - dataPlanSDR_945.json
# Loaded File - dataPlanSDR_946.json
# Loaded File - dataPlanSDR_947.json
# Loaded File - dataPlanSDR_948.json
# Loaded File - dataPlanSDR_949.json
# Loaded File - dataPlanSDR_950.json
# Loaded File - dataPlanSDR_951.json
# Loaded File - dataPlanSDR_952.json
# Loaded File - dataPlanSDR_953.json
# Loaded File - dataPlanSDR_954.json
# Loaded File - dataPlanSDR_955.json
# Loaded File - dataPlanSDR_956.json
# Loaded File - dataPlanSDR_957.json
# Loaded File - dataPlanSDR_958.json
# Loaded File - dataPlanSDR_959.json
# Loaded File - dataPlanSDR_960.json
# Loaded File - dataPlanSDR_961.json
# Loaded File - dataPlanSDR_962.json
# Loaded File - dataPlanSDR_963.json
# Loaded File - dataPlanSDR_964.json
# Loaded File - dataPlanSDR_965.json
# Loaded File - dataPlanSDR_966.json
# Loaded File - dataPlanSDR_967.json
# Loaded File - dataPlanSDR_968.json
# Loaded File - dataPlanSDR_969.json
# Loaded File - dataPlanSDR_970.json
# Loaded File - dataPlanSDR_971.json
# Loaded File - dataPlanSDR_972.json
# Loaded File - dataPlanSDR_973.json
# Loaded File - dataPlanSDR_974.json
# Loaded File - dataPlanSDR_975.json
# Loaded File - dataPlanSDR_976.json
# Loaded File - dataPlanSDR_977.json
# Loaded File - dataPlanSDR_978.json
# Loaded File - dataPlanSDR_979.json
# Loaded File - dataPlanSDR_980.json
# Loaded File - dataPlanSDR_981.json
# Loaded File - dataPlanSDR_982.json
# Loaded File - dataPlanSDR_983.json
# Loaded File - dataPlanSDR_984.json
# Loaded File - dataPlanSDR_985.json
# Loaded File - dataPlanSDR_986.json
# Loaded File - dataPlanSDR_987.json
# Loaded File - dataPlanSDR_988.json
# Loaded File - dataPlanSDR_989.json
# Loaded File - dataPlanSDR_990.json
# Loaded File - dataPlanSDR_991.json
# Loaded File - dataPlanSDR_992.json
# Loaded File - dataPlanSDR_993.json
# Loaded File - dataPlanSDR_994.json
# Loaded File - dataPlanSDR_995.json
# Loaded File - dataPlanSDR_996.json
# Loaded File - dataPlanSDR_997.json
# Loaded File - dataPlanSDR_998.json
# Loaded File - dataPlanSDR_999.json
# Loaded File - dataPlanSDR_1000.json
# Loaded File - dataPlanSDR_1001.json
# Loaded File - dataPlanSDR_1002.json
# Loaded File - dataPlanSDR_1003.json
# Loaded File - dataPlanSDR_1004.json
# Loaded File - dataPlanSDR_1005.json
# Loaded File - dataPlanSDR_1006.json
# Loaded File - dataPlanSDR_1007.json
# Loaded File - dataPlanSDR_1008.json
# Loaded File - dataPlanSDR_1009.json
# Loaded File - dataPlanSDR_1010.json
# Loaded File - dataPlanSDR_1011.json
# Loaded File - dataPlanSDR_1012.json
# Loaded File - dataPlanSDR_1013.json
# Loaded File - dataPlanSDR_1014.json
# Loaded File - dataPlanSDR_1015.json
# Loaded File - dataPlanSDR_1016.json
# Loaded File - dataPlanSDR_1017.json
# Loaded File - dataPlanSDR_1018.json
# Loaded File - dataPlanSDR_1019.json
# Loaded File - dataPlanSDR_1020.json
# Loaded File - dataPlanSDR_1021.json
# Loaded File - dataPlanSDR_1022.json
# Loaded File - dataPlanSDR_1023.json
# Loaded File - dataPlanSDR_1024.json
# Loaded File - dataPlanSDR_1025.json
# Loaded File - dataPlanSDR_1026.json
# Loaded File - dataPlanSDR_1027.json
# Loaded File - dataPlanSDR_1028.json
# Loaded File - dataPlanSDR_1029.json
# Loaded File - dataPlanSDR_1030.json
# Loaded File - dataPlanSDR_1031.json
# Loaded File - dataPlanSDR_1032.json
# Loaded File - dataPlanSDR_1033.json
# Loaded File - dataPlanSDR_1034.json
# Loaded File - dataPlanSDR_1035.json
# Loaded File - dataPlanSDR_1036.json
# Loaded File - dataPlanSDR_1037.json
# Loaded File - dataPlanSDR_1038.json
# Loaded File - dataPlanSDR_1039.json
# Loaded File - dataPlanSDR_1040.json
# Loaded File - dataPlanSDR_1041.json
# Loaded File - dataPlanSDR_1042.json
# Loaded File - dataPlanSDR_1043.json
# Loaded File - dataPlanSDR_1044.json
# Loaded File - dataPlanSDR_1045.json
# Loaded File - dataPlanSDR_1046.json
# Loaded File - dataPlanSDR_1047.json
# Loaded File - dataPlanSDR_1048.json
# Loaded File - dataPlanSDR_1049.json
# Loaded File - dataPlanSDR_1050.json
# Loaded File - dataPlanSDR_1051.json
# Loaded File - dataPlanSDR_1052.json
# Loaded File - dataPlanSDR_1053.json
# Loaded File - dataPlanSDR_1054.json
# Loaded File - dataPlanSDR_1055.json
# Loaded File - dataPlanSDR_1056.json
# Loaded File - dataPlanSDR_1057.json
# Loaded File - dataPlanSDR_1058.json
# Loaded File - dataPlanSDR_1059.json
# Loaded File - dataPlanSDR_1060.json
# Loaded File - dataPlanSDR_1061.json
# Loaded File - dataPlanSDR_1062.json
# Loaded File - dataPlanSDR_1063.json
# Loaded File - dataPlanSDR_1064.json
# Loaded File - dataPlanSDR_1065.json
# Loaded File - dataPlanSDR_1066.json
# Loaded File - dataPlanSDR_1067.json
# Loaded File - dataPlanSDR_1068.json
# Loaded File - dataPlanSDR_1069.json
# Loaded File - dataPlanSDR_1070.json
# Loaded File - dataPlanSDR_1071.json
# Loaded File - dataPlanSDR_1072.json
# Loaded File - dataPlanSDR_1073.json
# Loaded File - dataPlanSDR_1074.json
# Loaded File - dataPlanSDR_1075.json
# Loaded File - dataPlanSDR_1076.json
# Loaded File - dataPlanSDR_1077.json
# Loaded File - dataPlanSDR_1078.json
# Loaded File - dataPlanSDR_1079.json
# Loaded File - dataPlanSDR_1080.json
# Loaded File - dataPlanSDR_1081.json
# Loaded File - dataPlanSDR_1082.json
# Loaded File - dataPlanSDR_1083.json
# Loaded File - dataPlanSDR_1084.json
# Loaded File - dataPlanSDR_1085.json
# Loaded File - dataPlanSDR_1086.json
# Loaded File - dataPlanSDR_1087.json
# Loaded File - dataPlanSDR_1088.json
# Loaded File - dataPlanSDR_1089.json
# Loaded File - dataPlanSDR_1090.json
# Loaded File - dataPlanSDR_1091.json
# Loaded File - dataPlanSDR_1092.json
# Loaded File - dataPlanSDR_1093.json
# Loaded File - dataPlanSDR_1094.json
# Loaded File - dataPlanSDR_1095.json
# Loaded File - dataPlanSDR_1096.json
# Loaded File - dataPlanSDR_1097.json
# Loaded File - dataPlanSDR_1098.json
# Loaded File - dataPlanSDR_1099.json
# Loaded File - dataPlanSDR_1100.json
# Loaded File - dataPlanSDR_1101.json
# Loaded File - dataPlanSDR_1102.json
# Loaded File - dataPlanSDR_1103.json
# Loaded File - dataPlanSDR_1104.json
# Loaded File - dataPlanSDR_1105.json
# Loaded File - dataPlanSDR_1106.json
# Loaded File - dataPlanSDR_1107.json
# Loaded File - dataPlanSDR_1108.json
# Loaded File - dataPlanSDR_1109.json
# Loaded File - dataPlanSDR_1110.json
# Loaded File - dataPlanSDR_1111.json
# Loaded File - dataPlanSDR_1112.json
# Loaded File - dataPlanSDR_1113.json
# Loaded File - dataPlanSDR_1114.json
# Loaded File - dataPlanSDR_1115.json
# Loaded File - dataPlanSDR_1116.json
# Loaded File - dataPlanSDR_1117.json
# Loaded File - dataPlanSDR_1118.json
# Loaded File - dataPlanSDR_1119.json
# Loaded File - dataPlanSDR_1120.json
# Loaded File - dataPlanSDR_1121.json
# Loaded File - dataPlanSDR_1122.json
# Loaded File - dataPlanSDR_1123.json
# Loaded File - dataPlanSDR_1124.json
# Loaded File - dataPlanSDR_1125.json
# Loaded File - dataPlanSDR_1126.json
# Loaded File - dataPlanSDR_1127.json
# Loaded File - dataPlanSDR_1128.json
# Loaded File - dataPlanSDR_1129.json
# Loaded File - dataPlanSDR_1130.json
# Loaded File - dataPlanSDR_1131.json
# Loaded File - dataPlanSDR_1132.json
# Loaded File - dataPlanSDR_1133.json
# Loaded File - dataPlanSDR_1134.json
# Loaded File - dataPlanSDR_1135.json
# Loaded File - dataPlanSDR_1136.json
# Loaded File - dataPlanSDR_1137.json
# Loaded File - dataPlanSDR_1138.json
# Loaded File - dataPlanSDR_1139.json
# Loaded File - dataPlanSDR_1140.json
# Loaded File - dataPlanSDR_1141.json
# Loaded File - dataPlanSDR_1142.json
# Loaded File - dataPlanSDR_1143.json
# Loaded File - dataPlanSDR_1144.json
# Loaded File - dataPlanSDR_1145.json
# Loaded File - dataPlanSDR_1146.json
# Loaded File - dataPlanSDR_1147.json
# Loaded File - dataPlanSDR_1148.json
# Loaded File - dataPlanSDR_1149.json
# Loaded File - dataPlanSDR_1150.json
# Loaded File - dataPlanSDR_1151.json
# Loaded File - dataPlanSDR_1152.json
# Loaded File - dataPlanSDR_1153.json
# Loaded File - dataPlanSDR_1154.json
# Loaded File - dataPlanSDR_1155.json
# Loaded File - dataPlanSDR_1156.json
# Loaded File - dataPlanSDR_1157.json
# Loaded File - dataPlanSDR_1158.json
# Loaded File - dataPlanSDR_1159.json
# Loaded File - dataPlanSDR_1160.json
# Loaded File - dataPlanSDR_1161.json
# Loaded File - dataPlanSDR_1162.json
# Loaded File - dataPlanSDR_1163.json
# Loaded File - dataPlanSDR_1164.json
# Loaded File - dataPlanSDR_1165.json
# Loaded File - dataPlanSDR_1166.json
# Loaded File - dataPlanSDR_1167.json
# Loaded File - dataPlanSDR_1168.json
# Loaded File - dataPlanSDR_1169.json
# Loaded File - dataPlanSDR_1170.json
# Loaded File - dataPlanSDR_1171.json
# Loaded File - dataPlanSDR_1172.json
# Loaded File - dataPlanSDR_1173.json
# Loaded File - dataPlanSDR_1174.json
# Loaded File - dataPlanSDR_1175.json
# Loaded File - dataPlanSDR_1176.json
# Loaded File - dataPlanSDR_1177.json
# Loaded File - dataPlanSDR_1178.json
# Loaded File - dataPlanSDR_1179.json
# Loaded File - dataPlanSDR_1180.json
# Loaded File - dataPlanSDR_1181.json
# Loaded File - dataPlanSDR_1182.json
# Loaded File - dataPlanSDR_1183.json
# Loaded File - dataPlanSDR_1184.json
# Loaded File - dataPlanSDR_1185.json
# Loaded File - dataPlanSDR_1186.json
# Loaded File - dataPlanSDR_1187.json
# Loaded File - dataPlanSDR_1188.json
# Loaded File - dataPlanSDR_1189.json
# Loaded File - dataPlanSDR_1190.json
# Loaded File - dataPlanSDR_1191.json
# Loaded File - dataPlanSDR_1192.json
# Loaded File - dataPlanSDR_1193.json
# Loaded File - dataPlanSDR_1194.json
# Loaded File - dataPlanSDR_1195.json
# Loaded File - dataPlanSDR_1196.json
# Loaded File - dataPlanSDR_1197.json
# Loaded File - dataPlanSDR_1198.json
# Loaded File - dataPlanSDR_1199.json
# Loaded File - dataPlanSDR_1200.json
# Loaded File - dataPlanSDR_1201.json
# Loaded File - dataPlanSDR_1202.json
# Loaded File - dataPlanSDR_1203.json
# Loaded File - dataPlanSDR_1204.json
# Loaded File - dataPlanSDR_1205.json
# Loaded File - dataPlanSDR_1206.json
# Loaded File - dataPlanSDR_1207.json
# Loaded File - dataPlanSDR_1208.json
# Loaded File - dataPlanSDR_1209.json
# Loaded File - dataPlanSDR_1210.json
# Loaded File - dataPlanSDR_1211.json
# Loaded File - dataPlanSDR_1212.json
# Loaded File - dataPlanSDR_1213.json
# Loaded File - dataPlanSDR_1214.json
# Loaded File - dataPlanSDR_1215.json
# Loaded File - dataPlanSDR_1216.json
# Loaded File - dataPlanSDR_1217.json
# Loaded File - dataPlanSDR_1218.json
# Loaded File - dataPlanSDR_1219.json
# Loaded File - dataPlanSDR_1220.json
# Loaded File - dataPlanSDR_1221.json
# Loaded File - dataPlanSDR_1222.json
# Loaded File - dataPlanSDR_1223.json
# Loaded File - dataPlanSDR_1224.json
# Loaded File - dataPlanSDR_1225.json
# Loaded File - dataPlanSDR_1226.json
# Loaded File - dataPlanSDR_1227.json
# Loaded File - dataPlanSDR_1228.json
# Loaded File - dataPlanSDR_1229.json
# Loaded File - dataPlanSDR_1230.json
# Loaded File - dataPlanSDR_1231.json
# Loaded File - dataPlanSDR_1232.json
# Loaded File - dataPlanSDR_1233.json
# Loaded File - dataPlanSDR_1234.json
# Loaded File - dataPlanSDR_1235.json
# Loaded File - dataPlanSDR_1236.json
# Loaded File - dataPlanSDR_1237.json
# Loaded File - dataPlanSDR_1238.json
# Loaded File - dataPlanSDR_1239.json
# Loaded File - dataPlanSDR_1240.json
# Loaded File - dataPlanSDR_1241.json
# Loaded File - dataPlanSDR_1242.json
# Loaded File - dataPlanSDR_1243.json
# Loaded File - dataPlanSDR_1244.json
# Loaded File - dataPlanSDR_1245.json
# Loaded File - dataPlanSDR_1246.json
# Loaded File - dataPlanSDR_1247.json
# Loaded File - dataPlanSDR_1248.json
# Loaded File - dataPlanSDR_1249.json
# Loaded File - dataPlanSDR_1250.json
# Loaded File - dataPlanSDR_1251.json
# Loaded File - dataPlanSDR_1252.json
# Loaded File - dataPlanSDR_1253.json
# Loaded File - dataPlanSDR_1254.json
# Loaded File - dataPlanSDR_1255.json
# Loaded File - dataPlanSDR_1256.json
# Loaded File - dataPlanSDR_1257.json
# Loaded File - dataPlanSDR_1258.json
# Loaded File - dataPlanSDR_1259.json
# Loaded File - dataPlanSDR_1260.json
# Loaded File - dataPlanSDR_1261.json
# Loaded File - dataPlanSDR_1262.json
# Loaded File - dataPlanSDR_1263.json
# Loaded File - dataPlanSDR_1264.json
# Loaded File - dataPlanSDR_1265.json
# Loaded File - dataPlanSDR_1266.json
# Loaded File - dataPlanSDR_1267.json
# Loaded File - dataPlanSDR_1268.json
# Loaded File - dataPlanSDR_1269.json
# Loaded File - dataPlanSDR_1270.json
# Loaded File - dataPlanSDR_1271.json
# Loaded File - dataPlanSDR_1272.json
# Loaded File - dataPlanSDR_1273.json
# Loaded File - dataPlanSDR_1274.json
# Loaded File - dataPlanSDR_1275.json
# Loaded File - dataPlanSDR_1276.json
# Loaded File - dataPlanSDR_1277.json
# Loaded File - dataPlanSDR_1278.json
# Loaded File - dataPlanSDR_1279.json
# Loaded File - dataPlanSDR_1280.json
# Loaded File - dataPlanSDR_1281.json
# Loaded File - dataPlanSDR_1282.json
# Loaded File - dataPlanSDR_1283.json
# Loaded File - dataPlanSDR_1284.json
# Loaded File - dataPlanSDR_1285.json
# Loaded File - dataPlanSDR_1286.json
# Loaded File - dataPlanSDR_1287.json
# Loaded File - dataPlanSDR_1288.json
# Loaded File - dataPlanSDR_1289.json
# Loaded File - dataPlanSDR_1290.json
# Loaded File - dataPlanSDR_1291.json
# Loaded File - dataPlanSDR_1292.json
# Loaded File - dataPlanSDR_1293.json
# Loaded File - dataPlanSDR_1294.json
# Loaded File - dataPlanSDR_1295.json
# Loaded File - dataPlanSDR_1296.json
# Loaded File - dataPlanSDR_1297.json
# Loaded File - dataPlanSDR_1298.json
# Loaded File - dataPlanSDR_1299.json
# Loaded File - dataPlanSDR_1300.json
# Loaded File - dataPlanSDR_1301.json
# Loaded File - dataPlanSDR_1302.json
# Loaded File - dataPlanSDR_1303.json
# Loaded File - dataPlanSDR_1304.json
# Loaded File - dataPlanSDR_1305.json
# Loaded File - dataPlanSDR_1306.json
# Loaded File - dataPlanSDR_1307.json
# Loaded File - dataPlanSDR_1308.json
# Loaded File - dataPlanSDR_1309.json
# Loaded File - dataPlanSDR_1310.json
# Loaded File - dataPlanSDR_1311.json
# Loaded File - dataPlanSDR_1312.json
# Loaded File - dataPlanSDR_1313.json
# Loaded File - dataPlanSDR_1314.json
# Loaded File - dataPlanSDR_1315.json
# Loaded File - dataPlanSDR_1316.json
# Loaded File - dataPlanSDR_1317.json
# Loaded File - dataPlanSDR_1318.json
# Loaded File - dataPlanSDR_1319.json
# Loaded File - dataPlanSDR_1320.json
# Loaded File - dataPlanSDR_1321.json
# Loaded File - dataPlanSDR_1322.json
# Loaded File - dataPlanSDR_1323.json
# Loaded File - dataPlanSDR_1324.json
# Loaded File - dataPlanSDR_1325.json
# Loaded File - dataPlanSDR_1326.json
# Loaded File - dataPlanSDR_1327.json
# Loaded File - dataPlanSDR_1328.json
# Loaded File - dataPlanSDR_1329.json
# Loaded File - dataPlanSDR_1330.json
# Loaded File - dataPlanSDR_1331.json
# Loaded File - dataPlanSDR_1332.json
# Loaded File - dataPlanSDR_1333.json
# Loaded File - dataPlanSDR_1334.json
# Loaded File - dataPlanSDR_1335.json
# Loaded File - dataPlanSDR_1336.json
# Loaded File - dataPlanSDR_1337.json
# Loaded File - dataPlanSDR_1338.json
# Loaded File - dataPlanSDR_1339.json
# Loaded File - dataPlanSDR_1340.json
# Loaded File - dataPlanSDR_1341.json
# Loaded File - dataPlanSDR_1342.json
# Loaded File - dataPlanSDR_1343.json
# Loaded File - dataPlanSDR_1344.json
# Loaded File - dataPlanSDR_1345.json
# Loaded File - dataPlanSDR_1346.json
# Loaded File - dataPlanSDR_1347.json
# Loaded File - dataPlanSDR_1348.json
# Loaded File - dataPlanSDR_1349.json
# Loaded File - dataPlanSDR_1350.json
# Loaded File - dataPlanSDR_1351.json
# Loaded File - dataPlanSDR_1352.json
# Loaded File - dataPlanSDR_1353.json
# Loaded File - dataPlanSDR_1354.json
# Loaded File - dataPlanSDR_1355.json
# Loaded File - dataPlanSDR_1356.json
# Loaded File - dataPlanSDR_1357.json
# Loaded File - dataPlanSDR_1358.json
# Loaded File - dataPlanSDR_1359.json
# Loaded File - dataPlanSDR_1360.json
# Loaded File - dataPlanSDR_1361.json
# Loaded File - dataPlanSDR_1362.json
# Loaded File - dataPlanSDR_1363.json
# Loaded File - dataPlanSDR_1364.json
# ...
# Loaded File - dataPlanSDR_2055.json
# Loaded File - dataPlanSDR_2056.json
# Loaded File - dataPlanSDR_2057.json
# Loaded File - dataPlanSDR_2058.json
# Loaded File - dataPlanSDR_2059.json
# Loaded File - dataPlanSDR_2060.json
# Loaded File - dataPlanSDR_2061.json
# Loaded File - dataPlanSDR_2062.json
# Loaded File - dataPlanSDR_2063.json
# Loaded File - dataPlanSDR_2064.json
# Loaded File - dataPlanSDR_2065.json
# Loaded File - dataPlanSDR_2066.json
# Loaded File - dataPlanSDR_2067.json
# Loaded File - dataPlanSDR_2068.json
# Loaded File - dataPlanSDR_2069.json
# Loaded File - dataPlanSDR_2070.json
# Loaded File - dataPlanSDR_2071.json
# Loaded File - dataPlanSDR_2072.json
# Loaded File - dataPlanSDR_2073.json
# Loaded File - dataPlanSDR_2074.json
# Loaded File - dataPlanSDR_2075.json
# Loaded File - dataPlanSDR_2076.json
# Loaded File - dataPlanSDR_2077.json
# Loaded File - dataPlanSDR_2078.json
# Loaded File - dataPlanSDR_2079.json
# Loaded File - dataPlanSDR_2080.json
# Loaded File - dataPlanSDR_2081.json
# Loaded File - dataPlanSDR_2082.json
# Loaded File - dataPlanSDR_2083.json
# Loaded File - dataPlanSDR_2084.json
# Loaded File - dataPlanSDR_2085.json
# Loaded File - dataPlanSDR_2086.json
# Loaded File - dataPlanSDR_2087.json
# Loaded File - dataPlanSDR_2088.json
# Loaded File - dataPlanSDR_2089.json
# Loaded File - dataPlanSDR_2090.json
# Loaded File - dataPlanSDR_2091.json
# Loaded File - dataPlanSDR_2092.json
# Loaded File - dataPlanSDR_2093.json
# Loaded File - dataPlanSDR_2094.json
# Loaded File - dataPlanSDR_2095.json
# Loaded File - dataPlanSDR_2096.json
# Loaded File - dataPlanSDR_2097.json
# Loaded File - dataPlanSDR_2098.json
# Loaded File - dataPlanSDR_2099.json
# Loaded File - dataPlanSDR_2100.json
# Loaded File - dataPlanSDR_2101.json
# Loaded File - dataPlanSDR_2102.json
# Loaded File - dataPlanSDR_2103.json
# Loaded File - dataPlanSDR_2104.json
# Loaded File - dataPlanSDR_2105.json
# Loaded File - dataPlanSDR_2106.json
# Loaded File - dataPlanSDR_2107.json
# Loaded File - dataPlanSDR_2108.json
# Loaded File - dataPlanSDR_2109.json
# Loaded File - dataPlanSDR_2110.json
# Loaded File - dataPlanSDR_2111.json
# Loaded File - dataPlanSDR_2112.json
# Loaded File - dataPlanSDR_2113.json
# Loaded File - dataPlanSDR_2114.json
# Loaded File - dataPlanSDR_2115.json
# Loaded File - dataPlanSDR_2116.json
# Loaded File - dataPlanSDR_2117.json
# Loaded File - dataPlanSDR_2118.json
# Loaded File - dataPlanSDR_2119.json
# Loaded File - dataPlanSDR_2120.json
# Loaded File - dataPlanSDR_2121.json
# Loaded File - dataPlanSDR_2122.json
# Loaded File - dataPlanSDR_2123.json
# Loaded File - dataPlanSDR_2124.json
# Loaded File - dataPlanSDR_2125.json
# Loaded File - dataPlanSDR_2126.json
# Loaded File - dataPlanSDR_2127.json
# Loaded File - dataPlanSDR_2128.json
# Loaded File - dataPlanSDR_2129.json
# Loaded File - dataPlanSDR_2130.json
# Loaded File - dataPlanSDR_2131.json
# Loaded File - dataPlanSDR_2132.json
# Loaded File - dataPlanSDR_2133.json
# Loaded File - dataPlanSDR_2134.json
# Loaded File - dataPlanSDR_2135.json
# Loaded File - dataPlanSDR_2136.json
# Loaded File - dataPlanSDR_2137.json
# Loaded File - dataPlanSDR_2138.json
# Loaded File - dataPlanSDR_2139.json
# Loaded File - dataPlanSDR_2140.json
# Loaded File - dataPlanSDR_2141.json
# Loaded File - dataPlanSDR_2142.json
# Loaded File - dataPlanSDR_2143.json
# Loaded File - dataPlanSDR_2144.json
# Loaded File - dataPlanSDR_2145.json
# Loaded File - dataPlanSDR_2146.json
# Loaded File - dataPlanSDR_2147.json
# Loaded File - dataPlanSDR_2148.json
# Loaded File - dataPlanSDR_2149.json
# Loaded File - dataPlanSDR_2150.json
# Loaded File - dataPlanSDR_2151.json
# Loaded File - dataPlanSDR_2152.json
# Loaded File - dataPlanSDR_2153.json
# Loaded File - dataPlanSDR_2154.json
# Loaded File - dataPlanSDR_2155.json
# Loaded File - dataPlanSDR_2156.json
# Loaded File - dataPlanSDR_2157.json
# Loaded File - dataPlanSDR_2158.json
# Loaded File - dataPlanSDR_2159.json
# Loaded File - dataPlanSDR_2160.json
# Loaded File - dataPlanSDR_2161.json
# Loaded File - dataPlanSDR_2162.json
# Loaded File - dataPlanSDR_2163.json
# Loaded File - dataPlanSDR_2164.json
# Loaded File - dataPlanSDR_2165.json
# Loaded File - dataPlanSDR_2166.json
# Loaded File - dataPlanSDR_2167.json
# Loaded File - dataPlanSDR_2168.json
# Loaded File - dataPlanSDR_2169.json
# Loaded File - dataPlanSDR_2170.json
# Loaded File - dataPlanSDR_2171.json
# Loaded File - dataPlanSDR_2172.json
# Loaded File - dataPlanSDR_2173.json
# Loaded File - dataPlanSDR_2174.json
# Loaded File - dataPlanSDR_2175.json
# Loaded File - dataPlanSDR_2176.json
# Loaded File - dataPlanSDR_2177.json
# Loaded File - dataPlanSDR_2178.json
# Loaded File - dataPlanSDR_2179.json
# Loaded File - dataPlanSDR_2180.json
# Loaded File - dataPlanSDR_2181.json
# Loaded File - dataPlanSDR_2182.json
# Loaded File - dataPlanSDR_2183.json
# Loaded File - dataPlanSDR_2184.json
# Loaded File - dataPlanSDR_2185.json
# Loaded File - dataPlanSDR_2186.json
# Loaded File - dataPlanSDR_2187.json
# Loaded File - dataPlanSDR_2188.json
# Loaded File - dataPlanSDR_2189.json
# Loaded File - dataPlanSDR_2190.json
# Loaded File - dataPlanSDR_2191.json
# Loaded File - dataPlanSDR_2192.json
# Loaded File - dataPlanSDR_2193.json
# Loaded File - dataPlanSDR_2194.json
# Loaded File - dataPlanSDR_2195.json
# Loaded File - dataPlanSDR_2196.json
# Loaded File - dataPlanSDR_2197.json
# Loaded File - dataPlanSDR_2198.json
# Loaded File - dataPlanSDR_2199.json
# Loaded File - dataPlanSDR_2200.json
# Loaded File - dataPlanSDR_2201.json
# Loaded File - dataPlanSDR_2202.json
# Loaded File - dataPlanSDR_2203.json
# Loaded File - dataPlanSDR_2204.json
# Loaded File - dataPlanSDR_2205.json
# Loaded File - dataPlanSDR_2206.json
# Loaded File - dataPlanSDR_2207.json
# Loaded File - dataPlanSDR_2208.json
# Loaded File - dataPlanSDR_2209.json
# Loaded File - dataPlanSDR_2210.json
# Loaded File - dataPlanSDR_2211.json
# Loaded File - dataPlanSDR_2212.json
# Loaded File - dataPlanSDR_2213.json
# Loaded File - dataPlanSDR_2214.json
# Loaded File - dataPlanSDR_2215.json
# Loaded File - dataPlanSDR_2216.json
# Loaded File - dataPlanSDR_2217.json
# Loaded File - dataPlanSDR_2218.json
# Loaded File - dataPlanSDR_2219.json
# Loaded File - dataPlanSDR_2220.json
# Loaded File - dataPlanSDR_2221.json
# Loaded File - dataPlanSDR_2222.json
# Loaded File - dataPlanSDR_2223.json
# Loaded File - dataPlanSDR_2224.json
# Loaded File - dataPlanSDR_2225.json
# Loaded File - dataPlanSDR_2226.json
# Loaded File - dataPlanSDR_2227.json
# Loaded File - dataPlanSDR_2228.json
# Loaded File - dataPlanSDR_2229.json
# Loaded File - dataPlanSDR_2230.json
# Loaded File - dataPlanSDR_2231.json
# Loaded File - dataPlanSDR_2232.json
# Loaded File - dataPlanSDR_2233.json
# Loaded File - dataPlanSDR_2234.json
# Loaded File - dataPlanSDR_2235.json
# Loaded File - dataPlanSDR_2236.json
# Loaded File - dataPlanSDR_2237.json
# Loaded File - dataPlanSDR_2238.json
# Loaded File - dataPlanSDR_2239.json
# Loaded File - dataPlanSDR_2240.json
# Loaded File - dataPlanSDR_2241.json
# Loaded File - dataPlanSDR_2242.json
# Loaded File - dataPlanSDR_2243.json
# Loaded File - dataPlanSDR_2244.json
# Loaded File - dataPlanSDR_2245.json
# Loaded File - dataPlanSDR_2246.json
# Loaded File - dataPlanSDR_2247.json
# Loaded File - dataPlanSDR_2248.json
# Loaded File - dataPlanSDR_2249.json
# Loaded File - dataPlanSDR_2250.json
# Loaded File - dataPlanSDR_2251.json
# Loaded File - dataPlanSDR_2252.json
# Loaded File - dataPlanSDR_2253.json
# Loaded File - dataPlanSDR_2254.json
# Loaded File - dataPlanSDR_2255.json
# Loaded File - dataPlanSDR_2256.json
# Loaded File - dataPlanSDR_2257.json
# Loaded File - dataPlanSDR_2258.json
# Loaded File - dataPlanSDR_2259.json
# Loaded File - dataPlanSDR_2260.json
# Loaded File - dataPlanSDR_2261.json
# Loaded File - dataPlanSDR_2262.json
# Loaded File - dataPlanSDR_2263.json
# Loaded File - dataPlanSDR_2264.json
# Loaded File - dataPlanSDR_2265.json
# Loaded File - dataPlanSDR_2266.json
# Loaded File - dataPlanSDR_2267.json
# Loaded File - dataPlanSDR_2268.json
# Loaded File - dataPlanSDR_2269.json
# Loaded File - dataPlanSDR_2270.json
# Loaded File - dataPlanSDR_2271.json
# Loaded File - dataPlanSDR_2272.json
# Loaded File - dataPlanSDR_2273.json
# Loaded File - dataPlanSDR_2274.json
# Loaded File - dataPlanSDR_2275.json
# Loaded File - dataPlanSDR_2276.json
# Loaded File - dataPlanSDR_2277.json
# Loaded File - dataPlanSDR_2278.json
# Loaded File - dataPlanSDR_2279.json
# Loaded File - dataPlanSDR_2280.json
# Loaded File - dataPlanSDR_2281.json
# Loaded File - dataPlanSDR_2282.json
# Loaded File - dataPlanSDR_2283.json
# Loaded File - dataPlanSDR_2284.json
# Loaded File - dataPlanSDR_2285.json
# Loaded File - dataPlanSDR_2286.json
# Loaded File - dataPlanSDR_2287.json
# Loaded File - dataPlanSDR_2288.json
# Loaded File - dataPlanSDR_2289.json
# Loaded File - dataPlanSDR_2290.json
# Loaded File - dataPlanSDR_2291.json
# Loaded File - dataPlanSDR_2292.json
# Loaded File - dataPlanSDR_2293.json
# Loaded File - dataPlanSDR_2294.json
# Loaded File - dataPlanSDR_2295.json
# Loaded File - dataPlanSDR_2296.json
# Loaded File - dataPlanSDR_2297.json
# Loaded File - dataPlanSDR_2298.json
# Loaded File - dataPlanSDR_2299.json
# Loaded File - dataPlanSDR_2300.json
# Loaded File - dataPlanSDR_2301.json
# Loaded File - dataPlanSDR_2302.json
# Loaded File - dataPlanSDR_2303.json
# Loaded File - dataPlanSDR_2304.json
# Loaded File - dataPlanSDR_2305.json
# Loaded File - dataPlanSDR_2306.json
# Loaded File - dataPlanSDR_2307.json
# Loaded File - dataPlanSDR_2308.json
# Loaded File - dataPlanSDR_2309.json
# Loaded File - dataPlanSDR_2310.json
# Loaded File - dataPlanSDR_2311.json
# Loaded File - dataPlanSDR_2312.json
# Loaded File - dataPlanSDR_2313.json
# Loaded File - dataPlanSDR_2314.json
# Loaded File - dataPlanSDR_2315.json
# Loaded File - dataPlanSDR_2316.json
# Loaded File - dataPlanSDR_2317.json
# Loaded File - dataPlanSDR_2318.json
# Loaded File - dataPlanSDR_2319.json
# Loaded File - dataPlanSDR_2320.json
# Loaded File - dataPlanSDR_2321.json
# Loaded File - dataPlanSDR_2322.json
# Loaded File - dataPlanSDR_2323.json
# Loaded File - dataPlanSDR_2324.json
# Loaded File - dataPlanSDR_2325.json
# Loaded File - dataPlanSDR_2326.json
# Loaded File - dataPlanSDR_2327.json
# Loaded File - dataPlanSDR_2328.json
# Loaded File - dataPlanSDR_2329.json
# Loaded File - dataPlanSDR_2330.json
# Loaded File - dataPlanSDR_2331.json
# Loaded File - dataPlanSDR_2332.json
# Loaded File - dataPlanSDR_2333.json
# Loaded File - dataPlanSDR_2334.json
# Loaded File - dataPlanSDR_2335.json
# Loaded File - dataPlanSDR_2336.json
# Loaded File - dataPlanSDR_2337.json
# Loaded File - dataPlanSDR_2338.json
# Loaded File - dataPlanSDR_2339.json
# Loaded File - dataPlanSDR_2340.json
# Loaded File - dataPlanSDR_2341.json
# Loaded File - dataPlanSDR_2342.json
# Loaded File - dataPlanSDR_2343.json
# Loaded File - dataPlanSDR_2344.json
# Loaded File - dataPlanSDR_2345.json
# Loaded File - dataPlanSDR_2346.json
# Loaded File - dataPlanSDR_2347.json
# Loaded File - dataPlanSDR_2348.json
# Loaded File - dataPlanSDR_2349.json
# Loaded File - dataPlanSDR_2350.json
# Loaded File - dataPlanSDR_2351.json
# Loaded File - dataPlanSDR_2352.json
# Loaded File - dataPlanSDR_2353.json
# Loaded File - dataPlanSDR_2354.json
# Loaded File - dataPlanSDR_2355.json
# Loaded File - dataPlanSDR_2356.json
# Loaded File - dataPlanSDR_2357.json
# Loaded File - dataPlanSDR_2358.json
# Loaded File - dataPlanSDR_2359.json
# Loaded File - dataPlanSDR_2360.json
# Loaded File - dataPlanSDR_2361.json
# Loaded File - dataPlanSDR_2362.json
# Loaded File - dataPlanSDR_2363.json
# Loaded File - dataPlanSDR_2364.json
# Loaded File - dataPlanSDR_2365.json
# Loaded File - dataPlanSDR_2366.json
# Loaded File - dataPlanSDR_2367.json
# Loaded File - dataPlanSDR_2368.json
# Loaded File - dataPlanSDR_2369.json
# Loaded File - dataPlanSDR_2370.json
# Loaded File - dataPlanSDR_2371.json
# Loaded File - dataPlanSDR_2372.json
# Loaded File - dataPlanSDR_2373.json
# Loaded File - dataPlanSDR_2374.json
# Loaded File - dataPlanSDR_2375.json
# Loaded File - dataPlanSDR_2376.json
# Loaded File - dataPlanSDR_2377.json
# Loaded File - dataPlanSDR_2378.json
# Loaded File - dataPlanSDR_2379.json
# Loaded File - dataPlanSDR_2380.json
# Loaded File - dataPlanSDR_2381.json
# Loaded File - dataPlanSDR_2382.json
# Loaded File - dataPlanSDR_2383.json
# Loaded File - dataPlanSDR_2384.json
# Loaded File - dataPlanSDR_2385.json
# Loaded File - dataPlanSDR_2386.json
# Loaded File - dataPlanSDR_2387.json
# Loaded File - dataPlanSDR_2388.json
# Loaded File - dataPlanSDR_2389.json
# Loaded File - dataPlanSDR_2390.json
# Loaded File - dataPlanSDR_2391.json
# Loaded File - dataPlanSDR_2392.json
# Loaded File - dataPlanSDR_2393.json
# Loaded File - dataPlanSDR_2394.json
# Loaded File - dataPlanSDR_2395.json
# Loaded File - dataPlanSDR_2396.json
# Loaded File - dataPlanSDR_2397.json
# Loaded File - dataPlanSDR_2398.json
# Loaded File - dataPlanSDR_2399.json
# Loaded File - dataPlanSDR_2400.json
# Loaded File - dataPlanSDR_2401.json
# Loaded File - dataPlanSDR_2402.json
# Loaded File - dataPlanSDR_2403.json
# Loaded File - dataPlanSDR_2404.json
# Loaded File - dataPlanSDR_2405.json
# Loaded File - dataPlanSDR_2406.json
# Loaded File - dataPlanSDR_2407.json
# Loaded File - dataPlanSDR_2408.json
# Loaded File - dataPlanSDR_2409.json
# Loaded File - dataPlanSDR_2410.json
# Loaded File - dataPlanSDR_2411.json
# Loaded File - dataPlanSDR_2412.json
# Loaded File - dataPlanSDR_2413.json
# Loaded File - dataPlanSDR_2414.json
# Loaded File - dataPlanSDR_2415.json
# Loaded File - dataPlanSDR_2416.json
# Loaded File - dataPlanSDR_2417.json
# Loaded File - dataPlanSDR_2418.json
# Loaded File - dataPlanSDR_2419.json
# Loaded File - dataPlanSDR_2420.json
# Loaded File - dataPlanSDR_2421.json
# Loaded File - dataPlanSDR_2422.json
# Loaded File - dataPlanSDR_2423.json
# Loaded File - dataPlanSDR_2424.json
# Loaded File - dataPlanSDR_2425.json
# Loaded File - dataPlanSDR_2426.json
# Loaded File - dataPlanSDR_2427.json
# Loaded File - dataPlanSDR_2428.json
# Loaded File - dataPlanSDR_2429.json
# Loaded File - dataPlanSDR_2430.json
# Loaded File - dataPlanSDR_2431.json
# Loaded File - dataPlanSDR_2432.json
# Loaded File - dataPlanSDR_2433.json
# Loaded File - dataPlanSDR_2434.json
# Loaded File - dataPlanSDR_2435.json
# Loaded File - dataPlanSDR_2436.json
# Loaded File - dataPlanSDR_2437.json
# Loaded File - dataPlanSDR_2438.json
# Loaded File - dataPlanSDR_2439.json
# Loaded File - dataPlanSDR_2440.json
# Loaded File - dataPlanSDR_2441.json
# Loaded File - dataPlanSDR_2442.json
# Loaded File - dataPlanSDR_2443.json
# Loaded File - dataPlanSDR_2444.json
# Loaded File - dataPlanSDR_2445.json
# Loaded File - dataPlanSDR_2446.json
# Loaded File - dataPlanSDR_2447.json
# Loaded File - dataPlanSDR_2448.json
# Loaded File - dataPlanSDR_2449.json
# Loaded File - dataPlanSDR_2450.json
# Loaded File - dataPlanSDR_2451.json
# Loaded File - dataPlanSDR_2452.json
# Loaded File - dataPlanSDR_2453.json
# Loaded File - dataPlanSDR_2454.json
# Loaded File - dataPlanSDR_2455.json
# Loaded File - dataPlanSDR_2456.json
# Loaded File - dataPlanSDR_2457.json
# Loaded File - dataPlanSDR_2458.json
# Loaded File - dataPlanSDR_2459.json
# Loaded File - dataPlanSDR_2460.json
# Loaded File - dataPlanSDR_2461.json
# Loaded File - dataPlanSDR_2462.json
# Loaded File - dataPlanSDR_2463.json
# Loaded File - dataPlanSDR_2464.json
# Loaded File - dataPlanSDR_2465.json
# Loaded File - dataPlanSDR_2466.json
# Loaded File - dataPlanSDR_2467.json
# Loaded File - dataPlanSDR_2468.json
# Loaded File - dataPlanSDR_2469.json
# Loaded File - dataPlanSDR_2470.json
# Loaded File - dataPlanSDR_2471.json
# Loaded File - dataPlanSDR_2472.json
# Loaded File - dataPlanSDR_2473.json
# Loaded File - dataPlanSDR_2474.json
# Loaded File - dataPlanSDR_2475.json
# Loaded File - dataPlanSDR_2476.json
# Loaded File - dataPlanSDR_2477.json
# Loaded File - dataPlanSDR_2478.json
# Loaded File - dataPlanSDR_2479.json
# Loaded File - dataPlanSDR_2480.json
# Loaded File - dataPlanSDR_2481.json
# Loaded File - dataPlanSDR_2482.json
# Loaded File - dataPlanSDR_2483.json
# Loaded File - dataPlanSDR_2484.json
# Loaded File - dataPlanSDR_2485.json
# Loaded File - dataPlanSDR_2486.json
# Loaded File - dataPlanSDR_2487.json
# Loaded File - dataPlanSDR_2488.json
# Loaded File - dataPlanSDR_2489.json
# Loaded File - dataPlanSDR_2490.json
# Loaded File - dataPlanSDR_2491.json
# Loaded File - dataPlanSDR_2492.json
# Loaded File - dataPlanSDR_2493.json
# Loaded File - dataPlanSDR_2494.json
# Loaded File - dataPlanSDR_2495.json
# Loaded File - dataPlanSDR_2496.json
# Loaded File - dataPlanSDR_2497.json
# Loaded File - dataPlanSDR_2498.json

# %% [markdown]
# ### Spliting Data - Train and Validation

# %%
train_df, validation_df, test_df = \
              np.split(df.sample(frac=1, random_state=42),
                       [int(.7*len(df)), int(.85*len(df))])

train_size = len(train_df)

print("Train Size:" + str(len(train_df)))
print("Validation Size:" + str(len(validation_df)))
print("Test Size:" + str(len(test_df)))
# Out:
# Train Size:174915
# Validation Size:37482
# Test Size:37482
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %% [markdown]
# # Trainning

# %% [markdown]
# ## Hyperparameters

# %%
# Hyperparameters
vocabulary_size = len(dictionary_map['words'].keys())
d_model = 768  # Size of the transformer layers
nhead = 12  # Number of heads in the multiheadattention models
num_encoder_layers = 2  # Number of sub-encoder-layers in the encoder
num_decoder_layers = 4  # Number of sub-decoder-layers in the decoder
dim_feedforward = 768  # Dimension of the feedforward network model
dropout = 0.3  # Dropout value
learning_rate = 1e-4 # Learning rate
epochs = 100 # Epochs
NGPU = 1 # GPU Number
batch_size = 64
max_seq_len = 374

# %% [markdown]
# ## Instanciate data loaders

# %%
train_plan_dataset = PlanDataset(train_df)
train_data_loader = DataLoader(train_plan_dataset, batch_size=batch_size, shuffle=True)

validation_plan_dataset = PlanDataset(validation_df)
validation_data_loader = DataLoader(validation_plan_dataset, batch_size=batch_size, shuffle=True)

test_plan_dataset = PlanDataset(test_df)
test_data_loader = DataLoader(test_plan_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# ## Instanciate model

# %%
# Instantiate the model
gen = PlanningTransformer(vocabulary_size, d_model, nhead, num_encoder_layers, num_decoder_layers, dim_feedforward, dropout, max_seq_len, device).to(device)

# %%
if (device.type == 'cuda') and (NGPU > 1):
    gen = nn.DataParallel(gen, list(range(NGPU)))

gen.apply(weights_init)
# Out:
# PlanningTransformer(
#   (encoder_embedding): Embedding(33, 768)
#   (decoder_embedding): Embedding(33, 768)
#   (positional_encoding): PositionalEncoding()
#   (encoder_layers): ModuleList(
#     (0-1): 2 x EncoderLayer(
#       (self_attn): TransformerXLAttention(
#         (W_Q): Linear(in_features=768, out_features=768, bias=True)
#         (W_K): Linear(in_features=768, out_features=768, bias=True)
#         (W_V): Linear(in_features=768, out_features=768, bias=True)
#         (W_O): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#       )
#       (feed_forward): PositionWiseFeedForward(
#         (fc1): Linear(in_features=768, out_features=768, bias=True)
#         (fc2): Linear(in_features=768, out_features=768, bias=True)
#         (relu): ReLU()
#       )
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#   )
#   (decoder_layers): ModuleList(
#     (0-3): 4 x DecoderLayer(
#       (self_attn): TransformerXLAttention(
#         (W_Q): Linear(in_features=768, out_features=768, bias=True)
#         (W_K): Linear(in_features=768, out_features=768, bias=True)
#         (W_V): Linear(in_features=768, out_features=768, bias=True)
#         (W_O): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#       )
#       (cross_attn): TransformerXLAttention(
#         (W_Q): Linear(in_features=768, out_features=768, bias=True)
#         (W_K): Linear(in_features=768, out_features=768, bias=True)
#         (W_V): Linear(in_features=768, out_features=768, bias=True)
#         (W_O): Linear(in_features=768, out_features=768, bias=True)
#         (dropout): Dropout(p=0.3, inplace=False)
#       )
#       (feed_forward): PositionWiseFeedForward(
#         (fc1): Linear(in_features=768, out_features=768, bias=True)
#         (fc2): Linear(in_features=768, out_features=768, bias=True)
#         (relu): ReLU()
#       )
#       (norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (norm3): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.3, inplace=False)
#     )
#   )
#   (dropout): Dropout(p=0.3, inplace=False)
#   (output_layer): Linear(in_features=768, out_features=33, bias=True)
# )

# %% [markdown]
# ## Optimizers

# %%
opt_gen = optim.Adam(gen.parameters(), lr=learning_rate, betas=(0.9, 0.98), eps=1e-9)
lr_scheduler_gen = StepLR(opt_gen, step_size=5, gamma=0.9)

# %% [markdown]
# ## Training Method and Process

# %%
loss_train_list = []
v_loss_train_list = []

criterion = nn.CrossEntropyLoss(ignore_index=0)

# %%
def validate(model, validation_loader, epoch, epochs):

    v_loss_mean = 0
    v_batch_counter = 0

    model.eval()
    v_loop = tqdm(validation_data_loader)

    with torch.no_grad():
      for v_batch_idx, (v_input, v_label) in enumerate(v_loop):

        v_input = v_input.to(device)
        v_label = v_label.to(device)

        v_output = model(v_input, v_label[:,:-1])

        v_loss = criterion(v_output.view(-1, vocabulary_size), v_label[:, 1:].reshape(-1))
        v_loss_mean += v_loss.item()
        v_batch_counter += 1

        v_loop.set_description(f"Epoch [{epoch}/{epochs}] Validation Loss: {v_loss:.10f}")
        v_loop.refresh()

    return v_loss_mean / v_batch_counter

# %%
def train(model, optimizer, lr_scheduler, train_data_loader, validation_data_loader, epochs=5, retain_graph=True):
    step = 0
    best_val_loss = 1e10

    # Training
    for epoch in range(epochs):
      clear_output()
      loop = tqdm(train_data_loader)

      loss_mean = 0
      batch_counter = 0

      model.train()
      for batch_idx, (input, label) in enumerate(loop):

          input = input.to(device)
          label = label.to(device)

          output = model(input, label[:,:-1])

          loss = criterion(output.view(-1, vocabulary_size), label[:, 1:].reshape(-1))

          optimizer.zero_grad()
          loss.backward()
          optimizer.step()

          loss_mean += loss.item()
          batch_counter += 1

          loop.set_description(f"Epoch [{epoch}/{epochs}] Loss: {loss:.10f}")
          loop.refresh()

      loss_mean /= batch_counter

      lr_scheduler_gen.step()

      plt.title("CE Losses During Training/Validation")
      plt.plot(loss_train_list,label="CE")
      plt.plot(v_loss_train_list,label="VCE")
      plt.xlabel("Iterations")
      plt.ylabel("Losses")
      plt.legend()
      plt.show()

      v_loss_mean = validate(model, validation_data_loader, epoch, epochs)

      if v_loss_mean < best_val_loss:
        best_val_loss = v_loss_mean
        best_epoch = epoch
        torch.save(model.state_dict(), "/content/drive/MyDrive/data/models/generators/generator_P_SM_12_768_TRANS_E100_231024.pth")

      step+=1

      loss_train_list.append(loss_mean)
      v_loss_train_list.append(v_loss_mean)

# %%
train(gen, opt_gen, lr_scheduler, train_data_loader, validation_data_loader, epochs, retain_graph=False)
